# %% [markdown]
# 20250103 判断单仓内的线路，并把OK线路提取出来

# %%
import openpyxl
import requests
import json
import re,os
import warnings 
warnings.filterwarnings("ignore")

def respon_out(respon): #输入respond,判断线路、单仓和多仓
    mcang=re.search("storeHouse",respon,re.M|re.I)
    scang = re.search("urls",respon,re.M|re.I)
    xlu = re.search("sites",respon,re.M|re.I)
    if xlu is not None :
        return "H线路"
    elif xlu is  None and scang is not None and mcang is None:
        return "H单仓"
    elif xlu is  None and scang is  None and mcang is not None:
        return "H多仓"
    else :
        return "other"

def addlink(url): #增加代理链接
    agentlink="https://xn--sss604efuw.com/jm/jiemi.php?url="
    url1=agentlink+url
    return url1

def url_respon(url): #输入原始url,解析网站。返回：0-代理url；1-respone等元组；2-状态+200
    headers={"User-Agent":"okhttp/4.1.0"}
    try:
        respon=requests.get(url,verify=False,timeout =60)
        codema= respon.status_code
        if codema==200:
            if respon_out(respon.text)!='other': #如果解析结果不是other，则返回解析结果
                conten="首次解析状态:"+str(codema)
                outcang=respon_out(respon.text)
                # print(respon.text)
                return url,conten,outcang
            else:
                respon1=requests.get(url,headers=headers,verify=False,timeout =60)  #更换UA
                codema1= respon1.status_code
                conten1="更换UA状态: "+str(codema1)
                outcang1=respon_out(respon1.text)
                return url,conten1,outcang1
        else:
            respon2=requests.get(url=addlink(url),headers=headers,verify=False,timeout =60)  #增加代理2函数
            codema2= respon.status_code
            conten2="解析状态: "+str(codema2)
            outcang2=respon_out(respon2.text)
            return url,conten2,outcang2
    except Exception:
        # print("解析失败了!: ",url)
        return url,"失败状态：000","解析失败: "

def main():
    i=1
    # excel_file = r'D:\OneDrive\Learn\pythonLearn\TvBox\tvbox\excel_xianlu.xlsx' #家里路径
    excel_file = r'D:\lxd\learn\py\tvbox\excel_0103.xlsx' #公司路径
    workbook = openpyxl.load_workbook(filename=excel_file)
    sheet1= workbook['单仓']
    for row in sheet1.iter_rows(values_only=True):
        if not row is None :
            analysis_respone=url_respon(row[1]) 
            

            strtxt=analysis_respone[2] #返回解析结果,如单仓/多仓/失败
            codetxt=analysis_respone[1]  #返回 url的返回状态 如200，400
            # sheet1.cell(row = i,column = 4,value = strtxt)
            # sheet1.cell(row = i,column = 5,value = codetxt)

            print(strtxt,codetxt,row[1])
        else:
            break
        i=i+1
    # workbook.save(filename = "excel_0103sb2.xlsx")
    # print("__"*100)
if __name__ == '__main__':
    main()
# Out:
# H单仓 首次解析状态:200 https://xmbjm.github.io/ck.json
# H单仓 首次解析状态:200 https://4708.kstore.space/ck.json
# H单仓 首次解析状态:200 https://9877.kstore.space/FourDS/api.json
# H单仓 更换UA状态: 200 http://kxrj.site:55
# H单仓 首次解析状态:200 https://qixing.myhkw.com/DC.txt
# H单仓 首次解析状态:200 https://12586.kstore.space/123.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多影音.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多APP.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号应用边界.txt

# %% [markdown]
# 从其他py脚本中读取 单个url仓库，返回线路条数和线路

# %%
from KuSingleURL import mainx
import KuSingleURL
url="https://9877.kstore.space/FourDS/api.json"
url1="https://qixing.myhkw.com/DC.txt"
# mainx(url)
KuSingleURL.process_json(url)
# Out:
# 总线路条数： 41
# ðå¤©å¾®ViPçº¿ http://7337.kstore.space/twvip/%E8%87%AA%E7%94%A8%E6%B5%8B%E8%AF%95.json 线路成功
# 响应时间: 1.2699 秒;  内容长度: 47.38 KB
# ----------------------------------------------------------------------------------------------------
# ðä¸æå½±ä» https://11256.kstore.space/%E5%85%8D%E8%B4%B9%E5%8B%BF%E4%BC%A0.json 线路成功
# 响应时间: 1.6541 秒;  内容长度: 20.34 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðå°èæçº¿ https://hb.xyyh.online/tvbox/
# 响应时间: 26.7893 秒;  内容长度: 2.39 KB
# ----------------------------------------------------------------------------------------------------
# ðéªé¶çº¿è·¯ https://100km.top/0 线路成功
# 响应时间: 3.2493 秒;  内容长度: 12.38 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðå°é©¬çº¿è·¯ https://szyyds.cn/tv/x.json
# 响应时间: 1.5968 秒;  内容长度: 12.38 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðé¥­ç¡¬ä¸çº¿ http://www.é¥­å¤ªç¡¬.com/tv
# 响应时间: 0.0137 秒;  内容长度: 12.38 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðDä½¬é­æ¹ https://download.kstore.space/download/2883/nzk/nzk0722.json
# 响应时间: 1.6964 秒;  内容长度: 0.02 KB
# ----------------------------------------------------------------------------------------------------
# ðä¸è¯å¸çº¿ https://notabug.org/qizhen15800/My9394/raw/master/%e4%b8%8d%e8%89%af%e5%b8%85.json 线路成功
# 响应时间: 1.6364 秒;  内容长度: 31.97 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðé¾ä¼çº¿è·¯ https://é¾ä¼.top
# 响应时间: 0.0010 秒;  内容长度: 31.97 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðå°ç±³çº¿è·¯ http://www.mpanso.com/å°ç±³/DEMO.json
# 响应时间: 0.8540 秒;  内容长度: 3.77 KB
# ----------------------------------------------------------------------------------------------------
# ðéé¿çº¿è·¯ https://gitlab.com/duomv/dzhipy/-/raw/main/index.json 线路成功
# 响应时间: 2.3958 秒;  内容长度: 104.71 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðçäºå°çº¿ http://tvbox.çäºå°æ¾çå¨.xyz
# 响应时间: 0.0018 秒;  内容长度: 104.71 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðæåçº¿è·¯ https://ghproxy.liuzhicong.com/https://raw.githubusercontent.com/bestpvp/tm/main/source/stable/main.json
# 响应时间: 0.3357 秒;  内容长度: 104.71 KB
# ----------------------------------------------------------------------------------------------------
# ðç¯å®è½©çº¿ https://6492.kstore.space/xnf/xnf.json 线路成功
# 响应时间: 1.9907 秒;  内容长度: 88.76 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðæ½æ´ç©ºé´ https://cn.kstore.space/download/2863/01.txt
# 响应时间: 1.7385 秒;  内容长度: 0.02 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðå®ççº¿è·¯ http://mzjk.top/ç¦æ­¢è´©å
# 响应时间: 2.7940 秒;  内容长度: 0.14 KB
# ----------------------------------------------------------------------------------------------------
# ðé¦éæçº¿ https://gh-proxy.com/https://raw.githubusercontent.com/gaotianliuyun/gao/master/XYQ.json 线路成功
# 响应时间: 1.3435 秒;  内容长度: 17.54 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðæ¥çå¤©ä¸ https://gitlink.org.cn/api/hailin/aishangtv5/raw/tvbox/aishang.json?ref=master
# 响应时间: 4.4590 秒;  内容长度: 0.04 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðç¥ä»çº¿è·¯ http://dp.sxtv.top:88/img
# 响应时间: 2.7145 秒;  内容长度: 0.04 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前error ðä¸åçº¿è·¯ http://jin.é¦å¥å¥.love
# 响应时间: 0.0000 秒;  内容长度: 0.04 KB
# ----------------------------------------------------------------------------------------------------
# ðæºå¥½çº¿è·¯ https://ztha.top/TVBox/thdjk.json 线路成功
# 响应时间: 3.1872 秒;  内容长度: 15.57 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðèåçº¿è·¯ https://github.moeyy.xyz/https://raw.githubusercontent.com/liu673cn/box/main/m.json
# 响应时间: 1.1582 秒;  内容长度: 3.12 KB
# ----------------------------------------------------------------------------------------------------
# ðä¿ä½¬çº¿è·¯ http://home.jundie.top:81/top98.json 线路成功
# 响应时间: 1.7050 秒;  内容长度: 14.26 KB
# ----------------------------------------------------------------------------------------------------
# ðéé¾å½±çº¿ https://gitee.com/yiwu369/6758/raw/master/%E9%9D%92%E9%BE%99/1.json 线路成功
# 响应时间: 2.7236 秒;  内容长度: 13.77 KB
# ----------------------------------------------------------------------------------------------------
# ðè¶çº§çº¿è·¯ https://git.acwing.com/203BDXC/tvboxt/-/raw/main/CJ.json 线路成功
# 响应时间: 2.1674 秒;  内容长度: 41.43 KB
# ----------------------------------------------------------------------------------------------------
# 已删除当前失败 ðç½å«å½±çº¿ https://12448.kstore.space/Baipiao/tvbox/ç½å«4K.json
# 响应时间: 1.7086 秒;  内容长度: 0.00 KB
# ----------------------------------------------------------------------------------------------------
# 成功路线条数： 26
# 去除线路： 0
# 总成功路线： 26
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 url1="https://qixing.myhkw.com/DC.txt"
#       5 # mainx(url)
# ----> 6 KuSingleURL.process_json(url1)
#
# File d:\lxd\learn\py\tvbox\KuSingleURL.py:101, in process_json(url)
#      98 savejson2=json.dumps(dict2, indent=4, ensure_ascii=False)
#     100 # print(type(savejson2))
# --> 101 with open(filename, "w", encoding="utf-8") as file:
#     102     file.write(savejson2)
#     103     file.close()
#
# NameError: name 'filename' is not defined
