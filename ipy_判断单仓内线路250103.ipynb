# %% [markdown]
# 20250103 判断单仓内的线路，并把OK线路提取出来

# %%
import openpyxl
import requests
import json
import re,os
import warnings 
warnings.filterwarnings("ignore")

def respon_out(respon): #输入respond,判断线路、单仓和多仓
    mcang=re.search("storeHouse",respon,re.M|re.I)
    scang = re.search("urls",respon,re.M|re.I)
    xlu = re.search("sites",respon,re.M|re.I)
    if xlu is not None :
        return "H线路"
    elif xlu is  None and scang is not None and mcang is None:
        return "H单仓"
    elif xlu is  None and scang is  None and mcang is not None:
        return "H多仓"
    else :
        return "other"

def addlink(url): #增加代理链接
    agentlink="https://xn--sss604efuw.com/jm/jiemi.php?url="
    url1=agentlink+url
    return url1

def url_respon(url): #输入原始url,解析网站。返回：0-代理url；1-respone等元组；2-状态+200
    headers={"User-Agent":"okhttp/4.1.0"}
    try:
        respon=requests.get(url,verify=False,timeout =60)
        codema= respon.status_code
        if codema==200:
            if respon_out(respon.text)!='other': #如果解析结果不是other，则返回解析结果
                conten="首次解析状态:"+str(codema)
                outcang=respon_out(respon.text)
                # print(respon.text)
                return url,conten,outcang
            else:
                respon1=requests.get(url,headers=headers,verify=False,timeout =60)  #更换UA
                codema1= respon1.status_code
                conten1="更换UA状态: "+str(codema1)
                outcang1=respon_out(respon1.text)
                return url,conten1,outcang1
        else:
            respon2=requests.get(url=addlink(url),headers=headers,verify=False,timeout =60)  #增加代理2函数
            codema2= respon.status_code
            conten2="解析状态: "+str(codema2)
            outcang2=respon_out(respon2.text)
            return url,conten2,outcang2
    except Exception:
        # print("解析失败了!: ",url)
        return url,"失败状态：000","解析失败: "

def main():
    i=1
    # excel_file = r'D:\OneDrive\Learn\pythonLearn\TvBox\tvbox\excel_xianlu.xlsx' #家里路径
    excel_file = r'D:\lxd\learn\py\tvbox\excel_0103.xlsx' #公司路径
    workbook = openpyxl.load_workbook(filename=excel_file)
    sheet1= workbook['单仓']
    for row in sheet1.iter_rows(values_only=True):
        if not row is None :
            analysis_respone=url_respon(row[1]) 
            

            strtxt=analysis_respone[2] #返回解析结果,如单仓/多仓/失败
            codetxt=analysis_respone[1]  #返回 url的返回状态 如200，400
            # sheet1.cell(row = i,column = 4,value = strtxt)
            # sheet1.cell(row = i,column = 5,value = codetxt)

            print(strtxt,codetxt,row[1])
        else:
            break
        i=i+1
    # workbook.save(filename = "excel_0103sb2.xlsx")
    # print("__"*100)
if __name__ == '__main__':
    main()
# Out:
# H单仓 首次解析状态:200 https://xmbjm.github.io/ck.json
# H单仓 首次解析状态:200 https://4708.kstore.space/ck.json
# H单仓 首次解析状态:200 https://9877.kstore.space/FourDS/api.json
# H单仓 更换UA状态: 200 http://kxrj.site:55
# H单仓 首次解析状态:200 https://qixing.myhkw.com/DC.txt
# H单仓 首次解析状态:200 https://12586.kstore.space/123.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多影音.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多APP.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号应用边界.txt

# %% [markdown]
# 从其他py脚本中读取 单个url仓库，返回线路条数和线路
# 单独python文件执行，test1.py

# %%
# from KuSingleURL import mainx
import KuSingleURL
url="https://9877.kstore.space/FourDS/api.json"
url1="http://kxrj.site:55"  #这个有异常
# mainx(url)
KuSingleURL.process_json(url1,"999")

# url="https://9877.kstore.space/FourDS/api.json"
# url1="https://qixing.myhkw.com/DC.txt"
# # mainx(url)
# KuSingleURL.process_json(url,"12345")

# %% [markdown]
# 20250213

# %%
import openpyxl
import requests
import json
import re,os
import warnings 
warnings.filterwarnings("ignore")

def respon_out(respon): #输入respond,判断线路、单仓和多仓
    mcang=re.search("storeHouse",respon,re.M|re.I)
    scang = re.search("urls",respon,re.M|re.I)
    xlu = re.search("sites",respon,re.M|re.I)
    if xlu is not None :
        return "H线路"
    elif xlu is  None and scang is not None and mcang is None:
        return "H单仓"
    elif xlu is  None and scang is  None and mcang is not None:
        return "H多仓"
    else :
        return "other"

def addlink(url): #增加代理链接  # noqa: F811
    agentlink="https://xn--sss604efuw.com/jm/jiemi.php?url="
    url1=agentlink+url
    return url1

def url_respon(url): #输入原始url,解析网站。返回：0-代理url；1-respone等元组；2-状态+200  # noqa: F811
    headers={"User-Agent":"okhttp/4.1.0"}
    try:
        respon=requests.get(url,verify=False,timeout =60)
        codema= respon.status_code
        if codema==200:
            if respon_out(respon.text)!='other': #如果解析结果不是other，则返回解析结果
                conten="首次解析状态:"+str(codema)
                outcang=respon_out(respon.text)
                # print(respon.text)
                return url,conten,outcang
            else:
                respon1=requests.get(url,headers=headers,verify=False,timeout =60)  #更换UA
                codema1= respon1.status_code
                conten1="更换UA状态: "+str(codema1)
                outcang1=respon_out(respon1.text)
                return url,conten1,outcang1
        else:
            respon2=requests.get(url=addlink(url),headers=headers,verify=False,timeout =60)  #增加代理2函数
            codema2= respon.status_code
            conten2="解析状态: "+str(codema2)
            outcang2=respon_out(respon2.text)
            return url,conten2,outcang2
    except Exception:
        # print("解析失败了!: ",url)
        return url,"失败状态：000","解析失败: "

def main():
    i=1
    excel_file = r'D:\OneDrive\Learn\pythonLearn\TvBox\tvbox\excel_xianlu.xlsx' #家里路径
    # excel_file = r'D:\lxd\learn\py\tvbox\excel_0103.xlsx' #公司路径
    workbook = openpyxl.load_workbook(filename=excel_file)
    sheet1= workbook['0213']
    for row in sheet1.iter_rows(values_only=True):
        if row is not None :
            analysis_respone=url_respon(row[1]) 
            

            strtxt=analysis_respone[2] #返回解析结果,如单仓/多仓/失败
            codetxt=analysis_respone[1]  #返回 url的返回状态 如200，400
            # sheet1.cell(row = i,column = 4,value = strtxt)
            # sheet1.cell(row = i,column = 5,value = codetxt)

            print(strtxt,codetxt,row[1])
        else:
            break
        i=i+1
    workbook.save(filename = "excel_0213.xlsx")
    # print("__"*100)
if __name__ == '__main__':
    main()
# Out:
# H线路 首次解析状态:200 http://47.96.82.41:5188/
# H线路 首次解析状态:200 http://47.96.82.41:10/
# 解析失败:  失败状态：000 https://weixine.net/ysc.json
# H线路 首次解析状态:200 https://dxawi.github.io/0/0.json
# H线路 首次解析状态:200 https://raw.liucn.cc/box/m.json
# H线路 首次解析状态:200 https://notabug.org/qizhen15800/My9394/raw/master/ProfessionalEdition.m3u8
# H线路 首次解析状态:200 https://ghproxy.net/https://raw.githubusercontent.com/xiaolinshao/linshao/main/1.json
# H线路 首次解析状态:200 https://szyyds.cn/tv/x.json
# H线路 首次解析状态:200 https://gh-proxy.com/https://raw.githubusercontent.com/wnddwc/daiweichun/main/waynfifdwj.json
# H线路 首次解析状态:200 https://ghfast.top/https://raw.githubusercontent.com/xianyuyimu/TVBOX-/main/TVBox/%E4%B8%80%E6%9C%A8%E8%87%AA%E7%94%A8.json
# 解析失败:  失败状态：000 https://www.ywsj.cf/upload/2023/10/yyzq4k.json
# H线路 首次解析状态:200 https://notabug.org/liuyun/H-2023/raw/master/%E7%90%89%E8%8A%B8.json
# 解析失败:  失败状态：000 https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json
# 解析失败:  失败状态：000 https://raw.githubusercontent.com/YuanHsing/freed/master/TVBox/meow.json
# 解析失败:  失败状态：000 https://raw.githubusercontent.com/gaotianliuyun/gao/master/0825.json
# H线路 首次解析状态:200 http://xhztv.top/4k.json
# H线路 首次解析状态:200 https://gitee.com/yiwu369/6758/raw/master/%E9%9D%92%E9%BE%99/1.json
# H线路 首次解析状态:200 https://9xi4o.tk/0725.json
# H线路 首次解析状态:200 http://fmys.top/fmys.json
# 解析失败:  失败状态：000 http://tv.nxog.top/m
# H线路 首次解析状态:200 https://ghfast.top/https://raw.githubusercontent.com/FongMi/CatVodSpider/main/json/demo.json
# H线路 首次解析状态:200 https://gitee.com/lukei7/lib/raw/Luck/%E8%87%AA%E5%BB%BA.json
# 解析失败:  失败状态：000 https://ghproxy.net/https://raw.githubusercontent.com/xiaolinshao/linshao/main/18.json
# 解析失败:  失败状态：000 https://tv.nxog.top/m/111.php
# H线路 首次解析状态:200 https://git.acwing.com/ocean2025/ocean/-/raw/main/api.json
# H线路 首次解析状态:200 https://chuanshuo.77blog.cn/tv.json
# H线路 首次解析状态:200 http://xhztv.top/xhz/
# H线路 首次解析状态:200 https://ztha.top/TVBox/thdjk.json
# H线路 首次解析状态:200 http://www.mpanso.com/%E5%B0%8F%E7%B1%B3/DEMO.json
# H线路 首次解析状态:200 https://pandown.pro/tvbox/tvbox.json
# H线路 首次解析状态:200 http://home.jundie.top:81/top98.json
# H线路 首次解析状态:200 http://cdn.qiaoji8.com/tvbox.json
# H线路 首次解析状态:200 https://github.moeyy.xyz/https://raw.githubusercontent.com/xyq254245/xyqonlinerule/main/XYQTVBox.json
# 解析失败:  失败状态：000 https://raw.githubusercontent.com/gaotianliuyun/gao/master/0825.json
# H线路 首次解析状态:200 https://9xi4o.tk/0725.json
# H线路 首次解析状态:200 https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json

# %% [markdown]
# 20250607pm

# %%
import openpyxl
import requests
import json
import re,os
import warnings 
warnings.filterwarnings("ignore")

def respon_out(respon): #输入respond,判断线路、单仓和多仓
    mcang=re.search("storeHouse",respon,re.M|re.I)
    scang = re.search("urls",respon,re.M|re.I)
    xlu = re.search("sites",respon,re.M|re.I)
    if xlu is not None :
        return "H线路"
    elif xlu is  None and scang is not None and mcang is None:
        return "H单仓"
    elif xlu is  None and scang is  None and mcang is not None:
        return "H多仓"
    else :
        return "other"

def addlink(url): #增加代理链接  # noqa: F811
    agentlink="https://xn--sss604efuw.com/jm/jiemi.php?url="
    url1=agentlink+url
    return url1

def url_respon(url): #输入原始url,解析网站。返回：0-代理url；1-respone等元组；2-状态+200  # noqa: F811
    headers={"User-Agent":"okhttp/4.1.0"}
    try:
        respon=requests.get(url,verify=False,timeout =60)
        codema= respon.status_code
        if codema==200:
            if respon_out(respon.text)!='other': #如果解析结果不是other，则返回解析结果
                conten="首次解析状态:"+str(codema)
                outcang=respon_out(respon.text)
                # print(respon.text)
                return url,conten,outcang
            else:
                respon1=requests.get(url,headers=headers,verify=False,timeout =60)  #更换UA
                codema1= respon1.status_code
                conten1="更换UA状态: "+str(codema1)
                outcang1=respon_out(respon1.text)
                return url,conten1,outcang1
        else:
            respon2=requests.get(url=addlink(url),headers=headers,verify=False,timeout =60)  #增加代理2函数
            codema2= respon.status_code
            conten2="解析状态: "+str(codema2)
            outcang2=respon_out(respon2.text)
            return url,conten2,outcang2
    except Exception:
        # print("解析失败了!: ",url)
        return url,"失败状态：000","解析失败: "

def main():
    i=1
    excel_file = r'D:\OneDrive\Learn\pythonLearn\TvBox\tvbox\excel_0607jx.xlsx' #家里路径
    # excel_file = r'D:\lxd\learn\py\tvbox\excel_0103.xlsx' #公司路径
    workbook = openpyxl.load_workbook(filename=excel_file)
    sheet1= workbook['060701']
    for row in sheet1.iter_rows(values_only=True):
        if row is not None :
            analysis_respone=url_respon(row[1]) 
            strtxt=analysis_respone[2] #返回解析结果,如单仓/多仓/失败
            codetxt=analysis_respone[1]  #返回 url的返回状态 如200，400
            sheet1.cell(row = i,column = 4,value = strtxt)
            sheet1.cell(row = i,column = 5,value = codetxt)
            print(strtxt,codetxt,row[1])
        else:
            break
        i=i+1
    workbook.save(filename = "excel_0607jx1.xlsx")
    # print("__"*100)
if __name__ == '__main__':
    main()
# Out:
# 解析失败:  失败状态：000 None
# other 更换UA状态: 200 https://www.xn--rgv465a.top/musicfree.json
# other 更换UA状态: 200 https://www.xn--rgv465a.top/无界随机壁纸
# other 更换UA状态: 200 http://45.207.212.32:8000/txt
# other 更换UA状态: 200 https://www.xn--rgv465a.top/live/UpdatedWeekly.txt
# other 更换UA状态: 200 http://fty.xxooo.cf/tv
# other 更换UA状态: 200 http://ok321.top/tv
# other 更换UA状态: 200 http://ok321.top/ok
# other 更换UA状态: 200 http://fty.888484.xyz/tv
# other 更换UA状态: 200 https://jihulab.com/ymz1231/xymz/-/raw/main/ymshaoer
# 解析失败:  失败状态：000 https://raw.gitcode.com/yydg/ggdx/raw/main/Xboxb.json
# 解析失败:  失败状态：000 http://xmbjm.fh4u.org/dc.txt
# 解析失败:  失败状态：000 http://影视仓.com/duo
# 解析失败:  失败状态：000 https://bitbucket.org/xduo/cool/raw/main/line.json
# 解析失败:  失败状态：000 https://700sjro44343.vicp.fun/vip/2501/vip/tv.php
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多影音.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多应用汇.txt
# H单仓 首次解析状态:200 https://bitbucket.org/xduo/cool/raw/main/ck/公众号多多软件库.txt
# H线路 首次解析状态:200 https://jihulab.com/xuanzhuapp/xzys/-/raw/main/xzvip.json
# 解析失败:  失败状态：000 http://52pan.top:81/api/v3/file/get/174964/%E5%90%BE%E7%88%B1%E8%AF%84%E6%B5%8B.m3u?sign=rPssLoffquDXszCARt6UNF8MobSa1FA27XomzOluJBY%3D%3A0
# H线路 首次解析状态:200 https://www.yingm.cc/dm/dm.json
# other 更换UA状态: 200 http://meowtv.cn/tv
# H线路 首次解析状态:200 https://szyyds.cn/tv/x.json
# 解析失败:  失败状态：000 https://100km.top/0
# H线路 首次解析状态:200 https://dxawi.github.io/0/0.json
# 解析失败:  失败状态：000 https://api.hgyx.vip/hgyx.json
# H线路 首次解析状态:200 http://xhztv.top/xhz
# 解析失败:  失败状态：000 http://我不是.肥猫.live/接口禁止贩卖
# H线路 首次解析状态:200 http://我不是.摸鱼儿.top
# H线路 首次解析状态:200 https://毒盒.com/tv
# 解析失败:  失败状态：000 https://git.acwing.com/iduoduo/orange/-/raw/main/jsm.json
# 解析失败:  失败状态：000 https://download.kstore.space/download/2883/nzk/nzk0722.json
# 解析失败:  失败状态：000 http://dp.sxtv.top:88/img
# H线路 首次解析状态:200 http://home.jundie.top:81/top98.json
# 解析失败:  失败状态：000 http://bp.tvbox.cam
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=100&b=o?&brm
# H线路 首次解析状态:200 https://tv.youdu.fan:666/毒盒影视/
# H线路 首次解析状态:200 https://tv.youdu.fan:666/毒盒/
# H线路 首次解析状态:200 https://tv.youdu.fan:666/dhys/
# H线路 首次解析状态:200 https://tv.youdu.fan:666/dh/
# H线路 首次解析状态:200 https://d.kstore.dev/download/9347/tvbox/svip.json
# H线路 首次解析状态:200 http://tv.goos.gs:666
# H线路 首次解析状态:200 http://8.134.83.224:666
# H线路 首次解析状态:200 https://7337.kstore.space/twvip/%E8%87%AA%E7%94%A8%E6%B5%8B%E8%AF%95.json
# H线路 首次解析状态:200 https://o.nxog.top/m/111.php?ou=公众号欧歌app&mz=index&jar=index&123&b=o
# H线路 首次解析状态:200 https://o.nxog.top/m/111.php?ou=公众号欧歌app&mz=all&jar=all&b=o
# H线路 首次解析状态:200 https://o.nxog.top/m/111.php?ou=公众号欧歌app&mz=a3&jar=a3&b=o
# H线路 首次解析状态:200 https://o.nxog.top/m/333.php?ou=公众号欧歌app&mz=1&jar=index&321&b=o
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=1
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=2
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=3
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=4
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=5
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=6
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=7
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=8
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=9
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=10
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=11
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=12
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=13
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=14
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=15
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=16
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=17
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=18
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=19
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=20
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=21
# 解析失败:  失败状态：000 clan://localhost/TVBoxOSC/tvbox/api.json
# other 更换UA状态: 200 https://o.nxog.top/apitv.php?id=100&b=o
# H线路 首次解析状态:200 http://ztha.top/TVBox/thdjk.json
# 解析失败:  失败状态：000 http://www.fish2018.us.kg/p/jsm.json
# H线路 首次解析状态:200 https://ztha.top/1-zx/FongMi.json
# H线路 首次解析状态:200 http://tv.laohu.cool/tvbox.json
# other 更换UA状态: 200 http://www.饭太硬.com/tv
# H线路 首次解析状态:200 https://ghproxy.cn/https://raw.githubusercontent.com/leevi0709/one/main/jsm.json
# other 更换UA状态: 200 http://meowtv.top/tv
# 解析失败:  失败状态：000 http://175.178.251.183:6689/tv.txt
# H线路 首次解析状态:200 https://github.moeyy.xyz/https://raw.githubusercontent.com/yoursmile66/TVBox/main/XC.json
# H线路 首次解析状态:200 http://2883.kstore.space/nzk/nzk0722.json
# 解析失败:  失败状态：000 https://xn--yeto36i.v.xn--dkw.xn--6qq986b3xl/m/111.php?ou=公众号欧歌app&mz=index&jar=index&123&b=小赵
# 解析失败:  失败状态：000 https://4708.kstore.space/tvbox/api.json
# H线路 首次解析状态:200 https://bitbucket.org/xduo/duoapi/raw/master/xpg.json
# H线路 首次解析状态:200 https://qixing.myhkw.com/qxzj/七星智教
# 解析失败:  失败状态：000 http://www.mpanso.com/小米/DEMO.json
# 解析失败:  失败状态：000 http://www.fish2018.us.kg/z/FongMi.json
# H线路 首次解析状态:200 https://gitlab.com/duomv/dzhipy/-/raw/main/index.json
# H线路 更换UA状态: 200 http://tvbox.王二小放牛娃.top
# H线路 首次解析状态:200 http://我不是.摸鱼儿.com
# H线路 首次解析状态:200 https://6492.kstore.space/xnf/xnf.json
# H线路 首次解析状态:200 http://fmys.top/fmys.json
# 解析失败:  失败状态：000 http://t.lkkk.love/02.json
# 解析失败:  失败状态：000 http://mzjk.top/禁止贩卖
# H线路 更换UA状态: 200 https://tv.xn--yhqu5zs87a.top
# H线路 首次解析状态:200 https://gh-proxy.com/https://raw.githubusercontent.com/gaotianliuyun/gao/master/XYQ.json
# H线路 更换UA状态: 200 http://肥猫.com
# 解析失败:  失败状态：000 http://ttkx.cc:5869/天天开心
# H线路 首次解析状态:200 http://hucongrong.web3v.work/风水/fxz/fxz.json
# H线路 首次解析状态:200 https://www.lianyingtv.com/fast/fast
# H线路 首次解析状态:200 https://weixine.net/ysc.json
# H线路 首次解析状态:200 https://github.moeyy.xyz/https://raw.githubusercontent.com/liu673cn/box/main/m.json
# H线路 首次解析状态:200 https://gh-proxy.com/https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json
# H线路 首次解析状态:200 https://gitee.com/yiwu369/6758/raw/master/%E9%9D%92%E9%BE%99/1.json
# H线路 首次解析状态:200 http://74.120.175.78/JK/XYQTVBox/dj.json
