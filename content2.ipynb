# %% [markdown]
# ## 20240508

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    # scang="\"urls\": ["
    scang="\"urls\":"
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def findvalue1(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    pass

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回respone
    headers={
    "Cookie":"__test=d3d83bd5e2e46bec0866bd04dbc3f2e7",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url,headers=headers)
        # print(respon)
        codema= respon.status_code
        if codema==200:
            print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            return url,respon.text
        else:
            respon=requests.get(proxy_url,headers=headers)
            codema= respon.status_code
            print("代理后的网址返回状态： "+str(codema)+"- "+proxy_url)
            return proxy_url,respon.text
    except:
        try:
            respon=requests.get(proxy_url,headers=headers)
            # print(respon)
            codema= respon.status_code
            print("代理1后的网址返回状态： "+str(codema)+"- "+proxy_url)
            return proxy_url,respon.text
        except:
            print("解析失败： "+url)
            return "解析失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon
        cang=findvalue(analysis_respone[1])
        if cang=="H单仓":
            print("执行结果是:单仓 "+analysis_respone[0])
            # print("-"*20)
            # for url in extract_urls(exresponse) : #寻找批量的列表网址
            #     # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            #     print(findvalue(re_findall(url))+"-"+(url))
            # print("----\n")

        elif cang=="H多仓":
            print("执行结果是:多仓 "+analysis_respone[0])
        elif cang=="H线路":
            print("执行结果是:线路  "+analysis_respone[0])
        else:
            print("其他failure "+analysis_respone[0])
        print("="*30)
jiexi(url1)
jiexi(url2)
# # re_findall(url2)
# jiexi(url3)
# jiexi(url5)
# jiexi(url7)
# jiexi(url8)
# Out:
# 首次解析的网址返回状态： 200- http://rihou.vip:66/
# 其他failure http://rihou.vip:66/
# ...
# 代理后的网址返回状态： 200- http://lige.unaux.com/?url=http://xn--6orp08a.4tvbox.v6.navy/无敌.json
# 执行结果是:单仓 http://lige.unaux.com/?url=http://xn--6orp08a.4tvbox.v6.navy/无敌.json
# ...

# %%
import requests
url="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll
# respon=requests.get(addlink(url)).text
# print(respon)
uuu=addlink(url)
print(uuu)
headers={
    "Cookie":"__test=d3d83bd5e2e46bec0866bd04dbc3f2e7",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
codema= requests.get(uuu,headers=headers).status_code
print("代理后的网址返回状态： "+str(codema))

# %% [markdown]
# ## 全部检索

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    # scang="\"urls\": ["
    scang="\"urls\":"
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def findvalue1(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    pass

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回respone
    headers={
    "Cookie":"__test=d3d83bd5e2e46bec0866bd04dbc3f2e7",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    respon=requests.get(url,headers=headers)
    respon1=requests.get(proxy_url,headers=headers)  #增加代理函数
    try:
        
        # print(respon)
        codema= respon.status_code
        if codema==200:
            print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            return url,respon.text
        else:
            codema= respon1.status_code
            print("代理后的网址返回状态： "+str(codema)+"- "+proxy_url)
            return proxy_url,respon.text
    except:
        try:
            # print(respon)
            codema= respon1.status_code
            print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            return proxy_url,respon.text
        except:
            print("解析失败： "+url)
            return "解析失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon
        cang=findvalue(analysis_respone[1])
        if cang=="H单仓":
            print("执行结果是:单仓 "+analysis_respone[0])
            # print("-"*20)
            # for url in extract_urls(exresponse) : #寻找批量的列表网址
            #     # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            #     print(findvalue(re_findall(url))+"-"+(url))
            # print("----\n")

        elif cang=="H多仓":
            print("执行结果是:多仓 "+analysis_respone[0])
        elif cang=="H线路":
            print("执行结果是:线路  "+analysis_respone[0])
        else:
            print("其他failure ")#+analysis_respone[0])
        print("="*30)
# jiexi(url1)
# jiexi(url2)
# # re_findall(url2)
# jiexi(url3)
# jiexi(url5)
# jiexi(url7)
# jiexi(url8)

# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:

    for line in file:
        lineurl=line.strip()
        # print("|-"+lineurl)
        jiexi(lineurl)

# %% [markdown]
# 修改

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    # scang="\"urls\": ["
    scang="\"urls\":"
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def findvalue1(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    pass

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"__test=d3d83bd5e2e46bec0866bd04dbc3f2e7",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url)
        codema= respon.status_code
        if codema==200:
            print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            return url,respon.text
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema= respon1.status_code
            print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            return proxy_url,respon1.text
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema= respon2.status_code
            print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            return proxy_url,respon2.text
        except:
            print("解析失败： "+url)
            return "解析失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon
        cang=findvalue(analysis_respone[1])
        if cang=="H单仓":
            print("执行结果是:单仓 "+analysis_respone[0])
            # print("-"*20)
            # for url in extract_urls(exresponse) : #寻找批量的列表网址
            #     # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            #     print(findvalue(re_findall(url))+"-"+(url))
            # print("----\n")

        elif cang=="H多仓":
            print("执行结果是:多仓 "+analysis_respone[0])
        elif cang=="H线路":
            print("执行结果是:线路  "+analysis_respone[0])
        else:
            print("其他failure ")#+analysis_respone[0])
        print("="*30)
# jiexi(url1)
# jiexi(url2)
# # re_findall(url2)
# jiexi(url3)
# jiexi(url5)
# jiexi(url7)
# jiexi(url8)

# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:

    for line in file:
        lineurl=line.strip()
        # print("|-"+lineurl)
        jiexi(lineurl)
# Out:
# 代理2网址返回状态： 200- http://lige.unaux.com/?url=https://agit.ai/pinghui/xinghe/raw/branch/master/mayicang.txt
# 其他failure
# ...
# 代理2网址返回状态： 200- http://lige.unaux.com/?url=https://www.ywsj.cf/upload/2023/10/yyzq4k.json
# 执行结果是:线路  http://lige.unaux.com/?url=https://www.ywsj.cf/upload/2023/10/yyzq4k.json
# ...
# 代理1网址返回状态： 200- http://lige.unaux.com/?url=http://8.210.232.168/xc.json
# 执行结果是:线路  http://lige.unaux.com/?url=http://8.210.232.168/xc.json
# ...
# 代理1网址返回状态： 200- http://lige.unaux.com/?url=http://饭太硬.top/tv
# 执行结果是:线路  http://lige.unaux.com/?url=http://饭太硬.top/tv
# ...
# 代理2网址返回状态： 200- http://lige.unaux.com/?url=http://我不是.肥猫.love:63
# 其他failure
# ...
# 代理1网址返回状态： 200- http://lige.unaux.com/?url=https://gitee.com/shenxian2023/web/raw/master/sx.json
# 其他failure
# ...
# 代理2网址返回状态： 200- http://lige.unaux.com/?url=http://www.xzam.cn/xiaohu
# 其他failure
# ...
# 代理1网址返回状态： 200- http://lige.unaux.com/?url=https://tvbox.meitufu.com/TVBox/tv.json
# 执行结果是:线路  http://lige.unaux.com/?url=https://tvbox.meitufu.com/TVBox/tv.json
# ...

# %% [markdown]
# 优化单行显示

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    # scang="\"urls\": ["
    scang="\"urls\":"
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def findvalue1(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    pass

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"__test=d3d83bd5e2e46bec0866bd04dbc3f2e7",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url)
        codema= respon.status_code
        if codema==200:
            # print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            conten="首次解析的网址返回状态:"+str(codema)
            return url,respon.text,conten
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema1= respon1.status_code
            # print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            conten1="代理1网址返回状态: "+str(codema1)
            return proxy_url,respon1.text,conten1
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema2= respon2.status_code,conten
            # print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            conten2="代理2网址返回状态: "+str(codema2)
            return proxy_url,respon2.text,conten2
        except:
            print("解析失败： "+url)
            return "解析失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon，第三个是状态内容
        cang=findvalue(analysis_respone[1])
        if cang=="H单仓":
            print(analysis_respone[2]+" 单仓"+"-"+analysis_respone[0])
        elif cang=="H多仓":
            print(analysis_respone[2] +" 多仓"+"-"+analysis_respone[0])
        elif cang=="H线路":
            print(analysis_respone[2]+" 线路"+"-"+analysis_respone[0])
        else:
            # pass
            print(analysis_respone[2]+" 其他failure "+"-"+analysis_respone[0])
        # print("="*30)

# # re_findall(url2)
# jiexi(url1)
# # jiexi(url2)
# # jiexi(url3)
# jiexi(url5)
# # jiexi(url7)
# jiexi(url8)
# # jiexi(url9)

# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:
    for line in file:
        lineurl=line.strip()
        jiexi(lineurl)
# Out:
# 解析失败： https://agit.ai/pinghui/xinghe/raw/branch/master/mayicang.txt
# 失 其他failure -解
# 解析失败： https://www.ywsj.cf/upload/2023/10/yyzq4k.json
# 失 其他failure -解
# 代理1网址返回状态: 200 线路-http://lige.unaux.com/?url=http://8.210.232.168/xc.json
# 代理1网址返回状态: 200 线路-http://lige.unaux.com/?url=http://饭太硬.top/tv
# 解析失败： http://我不是.肥猫.love:63
# 失 其他failure -解
# 代理1网址返回状态: 200 其他failure -http://lige.unaux.com/?url=https://gitee.com/shenxian2023/web/raw/master/sx.json
# 解析失败： http://www.xzam.cn/xiaohu
# 失 其他failure -解
# 代理1网址返回状态: 200 线路-http://lige.unaux.com/?url=https://tvbox.meitufu.com/TVBox/tv.json
# 代理1网址返回状态: 200 其他failure -http://lige.unaux.com/?url=https://yydsys.top/duo
# 代理1网址返回状态: 200 其他failure -http://lige.unaux.com/?url=http://小盒酷玩.fun:66/
# 代理1网址返回状态: 200 其他failure -http://lige.unaux.com/?url=https://download.kstore.space/download/3313/app/ymzn
# 解析失败： ttps://jihulab.com/zhulr7765/tvbox/-/raw/main/tv.txt?ref_type=heads
# 失 其他failure -解
# ...

# %% [markdown]
# 20240509 am 逐行运行OK，但是判断单多can，线路有点出错。下面改用正则判断。

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    # scang="\"urls\": ["
    scang="\"urls\":"
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def findvalue1(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    pass

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"__test=d3d83bd5e2e46bec0866bd04dbc3f2e7",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url,headers=headers)
        codema= respon.status_code
        if codema==200:
            # print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            conten="首次解析的网址返回状态:"+str(codema)
            return url,respon.text,conten
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema1= respon1.status_code
            # print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            conten1="代理1网址返回状态: "+str(codema1)
            return proxy_url,respon1.text,conten1
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema2= respon2.status_code,conten
            # print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            conten2="代理2网址返回状态: "+str(codema2)
            return proxy_url,respon2.text,conten2
        except:
            content3="解析失败:"
            return url,"0",content3

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon，第三个是状态内容
        cang=findvalue(analysis_respone[1])
        if cang=="H单仓":
            print(analysis_respone[2]+" 单仓"+"-"+analysis_respone[0])
        elif cang=="H多仓":
            print(analysis_respone[2] +" 多仓"+"-"+analysis_respone[0])
        elif cang=="H线路":
            print(analysis_respone[2]+" 线路"+"-"+analysis_respone[0])
        else:
            # pass
            print(analysis_respone[2]+" 其他failure "+"-"+analysis_respone[0])
        # print("="*30)

# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:
    for line in file:
        lineurl=line.strip()
        jiexi(lineurl)

# %% [markdown]
# 20240509 am  正则尝试

# %%
import requests
import json
import re,os

def refindvalue(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    #mcang=re.search('storeHouse',respon,re.M|re.I).group()
    #scang = re.search('urls',respon,re.M|re.I).group()
    #xlu = re.search('sites',respon,re.M|re.I).group()
    try: #正常的操作
        mcang = re.search('storeHouse',respon,re.M|re.I).group()
    except :#发生异常，执行这块代码
        try:
            scang = re.search('urls',respon,re.M|re.I).group()
        except:#发生异常，执行这块代码
            try:
                xlu = re.search('sites',respon,re.M|re.I).group()
            except:#发生异常，执行这块代码
                return "正则失败"
            else: #如果没有异常执行这块代码
                return "H线路"
        else:
            return "H单仓"
    else:
        return "H多仓"
    
def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"Hm_lvt_d815f2e1f682c86565c1063aafaef292=1715176162; Hm_lpvt_d815f2e1f682c86565c1063aafaef292=1715176162; tfstk=fxg2k1gSVEL2a_igU8aaUOQXoJ4YWypCbVw_sfV4e-4scq_Z4XMWMi_ssRkZF8HaXIe_IRkssmOWReGxMPUg7pTBRYdKSDg4IOagkckz-p9BRUGxMPUMdc6Dftlz68fcjoDgru281Z4gnlXlqW2uIP4iI74uTSfcmZqGZ7DZTXhNG5ZDHRmfw4bLXoyngkQG747Q0Jc0UNV-zS7gKj2PSNwY5nQEaj9VJbaxZvPIhUbqLbGIku3wLErxrXu80VCN2bZL3z2xcK78gxGZ8u0D16wmyf0L4y-Od83tZDZL-tj0Try4xqD5sB40j540Hm9VySkj_2rooCsQwcD-7raHJt2sVXua_Vp9zvlSOqE-7p8l4NBTZ0ZxWmWGboV8aJOyZMO1RXe6S7PCXGEYo7yBizIGj9QN5iu6ZGITDWVzdI4O.; __test=1af893b932aa21ad543a801402580fba",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url,headers=headers)
        codema= respon.status_code
        if codema==200:
            # print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            conten="首次解析的网址返回状态:"+str(codema)
            return url,respon.text,conten
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema1= respon1.status_code
            # print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            conten1="代理1网址返回状态: "+str(codema1)
            return proxy_url,respon1.text,conten1
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema2= respon2.status_code,conten
            # print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            conten2="代理2网址返回状态: "+str(codema2)
            return proxy_url,respon2.text,conten2
        except:
            # print("解析失败： "+url)
            return url,"解析失败了: ","000"

url1="http://rihou.vip:66/"   #  -花式主页
url11="http://lige.unaux.com/?url=https://o.nxog.top/nxog/nxog1.php?b=欧歌" #多仓
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url4="https://tvbox.meitufu.com/TVBox/tv.json" #线路
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon，第三个是状态内容
        # cang=findvalue(analysis_respone[1])
        cang=refindvalue(analysis_respone[1])
        # print("shuchu--",cang,analysis_respone)

        if cang=="H单仓":
            print(analysis_respone[2]+" 单仓"+"-"+analysis_respone[0])
        elif cang=="H多仓":
            print(analysis_respone[2] +" 多仓"+"-"+analysis_respone[0])
        elif cang=="H线路":
            print(analysis_respone[2]+" 线路"+"-"+analysis_respone[0])
        else:
            # pass
            print(analysis_respone[2]+" 其他failure "+"-"+analysis_respone[0])
        print("="*30)


jiexi(url11)
jiexi(url1)
jiexi(url2)
jiexi(url3)
jiexi(url4)
jiexi(url5)

# re_findall(url4)
# Out:
# 首次解析的网址返回状态:200 多仓-http://lige.unaux.com/?url=https://o.nxog.top/nxog/nxog1.php?b=欧歌
# ...
# 首次解析的网址返回状态:200 其他failure -http://rihou.vip:66/
# ...
# 代理1网址返回状态: 200 单仓-http://lige.unaux.com/?url=http://xn--6orp08a.4tvbox.v6.navy/无敌.json
# ...
# 000 其他failure -https://agit.ai/leevi/PiG/raw/branch/master/jsm.json
# ...
# 代理1网址返回状态: 200 线路-http://lige.unaux.com/?url=https://tvbox.meitufu.com/TVBox/tv.json
# ...
# 代理1网址返回状态: 200 单仓-http://lige.unaux.com/?url=https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json
# ...

# %% [markdown]
# 02040509 pm 文本读取批量多行的网址解析，ok

# %%
import requests
import json
import re,os

def refindvalue(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    #mcang=re.search('storeHouse',respon,re.M|re.I).group()
    #scang = re.search('urls',respon,re.M|re.I).group()
    #xlu = re.search('sites',respon,re.M|re.I).group()
    try: #正常的操作
        mcang = re.search('storeHouse',respon,re.M|re.I).group()
    except :#发生异常，执行这块代码
        try:
            scang = re.search('urls',respon,re.M|re.I).group()
        except:#发生异常，执行这块代码
            try:
                xlu = re.search('sites',respon,re.M|re.I).group()
            except:#发生异常，执行这块代码
                return "正则失败"
            else: #如果没有异常执行这块代码
                return "H线路"
        else:
            return "H单仓"
    else:
        return "H多仓"
    
def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"Hm_lvt_d815f2e1f682c86565c1063aafaef292=1715176162; Hm_lpvt_d815f2e1f682c86565c1063aafaef292=1715176162; tfstk=fxg2k1gSVEL2a_igU8aaUOQXoJ4YWypCbVw_sfV4e-4scq_Z4XMWMi_ssRkZF8HaXIe_IRkssmOWReGxMPUg7pTBRYdKSDg4IOagkckz-p9BRUGxMPUMdc6Dftlz68fcjoDgru281Z4gnlXlqW2uIP4iI74uTSfcmZqGZ7DZTXhNG5ZDHRmfw4bLXoyngkQG747Q0Jc0UNV-zS7gKj2PSNwY5nQEaj9VJbaxZvPIhUbqLbGIku3wLErxrXu80VCN2bZL3z2xcK78gxGZ8u0D16wmyf0L4y-Od83tZDZL-tj0Try4xqD5sB40j540Hm9VySkj_2rooCsQwcD-7raHJt2sVXua_Vp9zvlSOqE-7p8l4NBTZ0ZxWmWGboV8aJOyZMO1RXe6S7PCXGEYo7yBizIGj9QN5iu6ZGITDWVzdI4O.; __test=1af893b932aa21ad543a801402580fba",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url,headers=headers)
        codema= respon.status_code
        if codema==200:
            # print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            conten="首次解析状态:"+str(codema)
            return url,respon.text,conten
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema1= respon1.status_code
            # print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            conten1="代理1网址状态: "+str(codema1)
            return proxy_url,respon1.text,conten1
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema2= respon2.status_code,conten
            # print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            conten2="代理2网址状态: "+str(codema2)
            return proxy_url,respon2.text,conten2
        except:
            # print("解析失败： "+url)
            return url,"000","解析失败了: "

url1="http://rihou.vip:66/"   #  -花式主页
url11="http://lige.unaux.com/?url=https://o.nxog.top/nxog/nxog1.php?b=欧歌" #多仓
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url4="https://tvbox.meitufu.com/TVBox/tv.json" #线路
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon，第三个是状态内容
        # cang=findvalue(analysis_respone[1])
        cang=refindvalue(analysis_respone[1])
        # print("shuchu--",cang,analysis_respone)

        if cang=="H单仓":
            print(analysis_respone[2]+" 单仓"+"-"+analysis_respone[0])
        elif cang=="H多仓":
            print(analysis_respone[2] +" 多仓"+"-"+analysis_respone[0])
        elif cang=="H线路":
            print(analysis_respone[2]+" 线路"+"-"+analysis_respone[0])
        else:
            # pass
            print(analysis_respone[2]+" 其他failure "+"-"+analysis_respone[0])
        # print("="*30)

# jiexi(url11)
# jiexi(url1)
# jiexi(url2)
# jiexi(url3)
# jiexi(url4)
# jiexi(url5)

# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:
    for line in file:
        lineurl=line.strip()
        jiexi(lineurl)
# Out:
# 解析失败了:  其他failure -https://agit.ai/pinghui/xinghe/raw/branch/master/mayicang.txt
# 解析失败了:  其他failure -https://www.ywsj.cf/upload/2023/10/yyzq4k.json
# 代理1网址状态: 200 线路-http://lige.unaux.com/?url=http://8.210.232.168/xc.json
# 代理1网址状态: 200 线路-http://lige.unaux.com/?url=http://饭太硬.top/tv
# 解析失败了:  其他failure -http://我不是.肥猫.love:63
# 解析失败了:  其他failure -https://gitee.com/shenxian2023/web/raw/master/sx.json
# 解析失败了:  其他failure -http://www.xzam.cn/xiaohu
# 解析失败了:  其他failure -https://tvbox.meitufu.com/TVBox/tv.json
# 解析失败了:  其他failure -https://yydsys.top/duo
# 解析失败了:  其他failure -http://小盒酷玩.fun:66/
# 解析失败了:  其他failure -https://download.kstore.space/download/3313/app/ymzn
# 解析失败了:  其他failure -ttps://jihulab.com/zhulr7765/tvbox/-/raw/main/tv.txt?ref_type=heads
# 解析失败了:  其他failure -https://raw.gitmirror.com/yydfys/yydf/main/yydf/yydf.json
# 解析失败了:  其他failure -https://weixine.net/ysc.json
# 解析失败了:  其他failure -https://cf.weixine.net/ysc.json
# 解析失败了:  其他failure -http://52bsj.vip:98/cl
# ...

# %% [markdown]
# ---

# %% [markdown]
# 20240509 PM 尝试 单仓 解析成线路
# 删除无效路线

# %%
import requests
import json
import re,os

def refindvalue(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    #mcang=re.search('storeHouse',respon,re.M|re.I).group()
    #scang = re.search('urls',respon,re.M|re.I).group()
    #xlu = re.search('sites',respon,re.M|re.I).group()
    try: #正常的操作
        mcang = re.search('storeHouse',respon,re.M|re.I).group()
    except :#发生异常，执行这块代码
        try:
            scang = re.search('urls',respon,re.M|re.I).group()
        except:#发生异常，执行这块代码
            try:
                xlu = re.search('sites',respon,re.M|re.I).group()
            except:#发生异常，执行这块代码
                return "正则失败"
            else: #如果没有异常执行这块代码
                return "H线路"
        else:
            return "H单仓"
    else:
        return "H多仓"
    
def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"Hm_lvt_d815f2e1f682c86565c1063aafaef292=1715176162; Hm_lpvt_d815f2e1f682c86565c1063aafaef292=1715176162; tfstk=fxg2k1gSVEL2a_igU8aaUOQXoJ4YWypCbVw_sfV4e-4scq_Z4XMWMi_ssRkZF8HaXIe_IRkssmOWReGxMPUg7pTBRYdKSDg4IOagkckz-p9BRUGxMPUMdc6Dftlz68fcjoDgru281Z4gnlXlqW2uIP4iI74uTSfcmZqGZ7DZTXhNG5ZDHRmfw4bLXoyngkQG747Q0Jc0UNV-zS7gKj2PSNwY5nQEaj9VJbaxZvPIhUbqLbGIku3wLErxrXu80VCN2bZL3z2xcK78gxGZ8u0D16wmyf0L4y-Od83tZDZL-tj0Try4xqD5sB40j540Hm9VySkj_2rooCsQwcD-7raHJt2sVXua_Vp9zvlSOqE-7p8l4NBTZ0ZxWmWGboV8aJOyZMO1RXe6S7PCXGEYo7yBizIGj9QN5iu6ZGITDWVzdI4O.; __test=1af893b932aa21ad543a801402580fba",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url,headers=headers)
        codema= respon.status_code
        if codema==200:
            # print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            conten="首次解析状态:"+str(codema)
            return url,respon.text,conten
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema1= respon1.status_code
            # print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            conten1="代理1网址状态: "+str(codema1)
            return proxy_url,respon1.text,conten1
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema2= respon2.status_code,conten
            # print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            conten2="代理2网址状态: "+str(codema2)
            return proxy_url,respon2.text,conten2
        except:
            # print("解析失败： "+url)
            return url,"000","解析失败了: "

url1="http://rihou.vip:66/"   #  -花式主页
url11="http://lige.unaux.com/?url=https://o.nxog.top/nxog/nxog1.php?b=欧歌" #多仓
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url4="https://tvbox.meitufu.com/TVBox/tv.json" #线路
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url55="http://lige.unaux.com/?url=http://wl.iptv8.top/wl/a/1706600423.txt"
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexidc(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon，第三个是状态内容
        # print(analysis_respone[2]+" 单仓"+"-"+analysis_respone[0]+"\n"+analysis_respone[1])#+analysis_respone[1])
        text=analysis_respone[1]
        json_str = text[text.index('{'):text.rindex('}')+1]  # 提取JSON字符串
        # print(text,json_str)
        jsondata = json.loads(json_str)
        datas=jsondata['urls']
        x=len(datas)
        print('总线路条数：',x)
        for data in datas:
            testurl=data['url']
            try:
                rnse = requests.get(testurl,verify=False,timeout =60)
                if rnse.status_code==200:
                    print(data['name'],data['url'],"成功",)
                else:
                    # print(data['name'],data['url'],"失败")
                    datas.remove(data)
                    print('已删除当前失败',data['name'])
            except Exception:
                # print(data['name'],data['url'],"error")
                datas.remove(data)
                print('已删除当前error',data['name'])
            else:
                pass
            finally:
                pass
        y=len(datas) #成功路线
        print('成功路线条数：',y)
        dict2={}
        dict2['urls']=datas
        savejson2=json.dumps(dict2, indent=4, ensure_ascii=False)
        with open('tvboxdcjx.json', "w", encoding="utf-8") as file:
            file.write(savejson2)
            file.close()
jiexidc(url55)
# Out:
# 首次解析状态:200 单仓-http://lige.unaux.com/?url=http://wl.iptv8.top/wl/a/1706600423.txt
# <html><body><script type="text/javascript" src="/aes.js" ></script><script>function toNumbers(d){var e=[];d.replace(/(..)/g,function(d){e.push(parseInt(d,16))});return e}function toHex(){for(var d=[],d=1==arguments.length&&arguments[0].constructor==Array?arguments[0]:arguments,e="",f=0;f<d.length;f++)e+=(16>d[f]?"0":"")+d[f].toString(16);return e.toLowerCase()}var a=toNumbers("f655ba9d09a112d4968c63579db590b4"),b=toNumbers("98344c2eee86c3994890592585b49f80"),c=toNumbers("a7be25dd2fbff5d24421d7968277f518");document.cookie="__test="+toHex(slowAES.decrypt(c,2,a,b))+"; expires=Thu, 31-Dec-37 23:55:55 GMT; path=/"; location.href="http://lige.unaux.com/?url=http://wl.iptv8.top/wl/a/1706600423.txt&i=1";</script><noscript>This site requires Javascript to work, please enable Javascript in your browser or use a browser with Javascript support</noscript></body></html>
# ...
