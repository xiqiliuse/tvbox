# %%
import requests
import json

def is_response_json(response):
    """
    判断给定的HTTP响应内容是否为有效的JSON格式。

    参数:
        response (requests.Response): HTTP响应对象

    返回:
        bool: 如果响应内容是JSON格式，返回True；否则返回False
    """
    try:
        json.loads(response.text)
        return True
    except json.JSONDecodeError:
        return False

# 示例请求
url = "http://lige.unaux.com/?url=http://rihou.vip:66/"
response = requests.get(url)

if is_response_json(response):
    print("网页返回的数据是JSON格式")
    print(response.text)
else:
    print("网页返回的数据不是JSON格式")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 22
#      20 # 示例请求
#      21 url = "http://lige.unaux.com/?url=http://rihou.vip:66/"
# ---> 22 response = requests.get(url)
#      24 if is_response_json(response):
#      25     print("网页返回的数据是JSON格式")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ## 线路有效

# %%
import requests
import json




def findvalue(respon):
    mcang="storeHouse"
    scang="{\"urls\""
    xlu="spider"

    if respon.find(mcang) != -1:
        duocang = respon.find(mcang)
        print("多仓"+ str(mcang))
    elif respon.find(scang) != -1:
        dancang=respon.find(scang)
        print("单仓" + str(scang))
    elif respon.find(xlu) != -1:
        xianlu=respon.find(xlu)
        print("线路"+ str(xlu)) 
    else:
        print("没有找到")

url1="http://rihou.vip:66/"
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json"

agentlink="http://fly.lyin.cf/?url="
urll=agentlink+url5
respon=requests.get(urll).text
# respon=requests.get(url3).content

findvalue(respon)
print(respon)

# %%
import re
import requests
import json

def extract_urls(text):
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    print(type(urls))
    return urls

urls="http://fly.lyin.cf/?url=http://xn--6orp08a.4tvbox.v6.navy/%E6%97%A0%E6%95%8C.json"
respon=requests.get(urls).text

found_urls = extract_urls(respon)
for url in found_urls:
    print(url)

# %%
import requests
import json
import re

def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls


def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="{\"urls\""
    xlu="spider"

    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="H-/-不通畅"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    urll=agentlink+url
    return urll

def re_findall(url): #返回respone
    respon=requests.get(addlink(url)).text
    return respon

#------------------------------------------
url1="http://rihou.vip:66/"
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"

urlink=addlink(url3) #增加代理链接
# print("代理路线是: "+urlink)

msx=findvalue(re_findall(urlink))  #判断单仓多仓,返回cang自定义文本
print(msx)
if msx=="H多仓":
    print("多仓zx: "+urlink)
elif msx=="H单仓":
    print("单仓zx: "+urlink)
    for url in extract_urls(re_findall(urlink)) : #寻找批量的列表网址
        print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
    print("----\n")
elif msx=="H线路":
    print("线路通畅zx: "+urlink)
else:
    print("400吧 "+urlink)
# Out:
# H线路
# 线路通畅zx: http://fly.lyin.cf/?url=https://agit.ai/leevi/PiG/raw/branch/master/jsm.json

# %%
## 调试

# %%
import requests
import json
import re



def findvalue(respon): #输入str文本。判断单仓多仓，返回判断值
    mcang="storeHouse"
    scang="{\"urls\""
    xlu="spider"

    if respon.find(mcang) != -1:
        cang = "多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="单仓" #+ respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="线路通畅"#+ respon.find(xlu)
    else:
        cang="没有找到或者线路不通畅"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    urll=agentlink+url
    return urll

#------------------------------------------
url1="http://rihou.vip:66/"
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"

respon=requests.get(addlink(url3)).text

# found_urls = extract_urls(respon) #寻找批量的列表网址
# for url in found_urls:

print(addlink(url3))
# print(respon)
findvalue(respon)


# findvalue(respon)
# print(respon)
# Out:
# http://fly.lyin.cf/?url=https://agit.ai/leevi/PiG/raw/branch/master/jsm.json
# '线路通畅'

# %% [markdown]
# ## 查询 单仓多仓 线路有效

# %%
import requests
import json
import re

def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls


def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="{\"urls\""
    xlu="spider"

    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="=_H_=不通畅"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    urll=agentlink+url
    return urll

def re_findall(url): #返回respone
    respon=requests.get(addlink(url)).text
    return respon

#------------------------------------------
url1="http://rihou.vip:66/"
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json"
urlink=addlink(url5) #增加代理链接

# print("代理路线是: "+urlink)

msx=findvalue(re_findall(urlink))  #判断单仓多仓,返回cang自定义文本
print(msx)
if msx=="H多仓":
    print("多仓zx: "+urlink)
elif msx=="H单仓":
    print("单仓zx: "+urlink)
    for url in extract_urls(re_findall(urlink)) : #寻找批量的列表网址
        print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
    print("----\n")
elif msx=="H线路":
    print("线路通畅zx: "+urlink)
else:
    print("400吧 "+urlink)

# %% [markdown]
# ---
# ## 20240429

# %% [markdown]
# resquests使用代理增访问，返回的json信息

# %%
import requests

url="http://lige.unaux.com/?url=http://rihou.vip:66/"
url2="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt"
url1="http://lige.unaux.com/?url=http://530.my3v.work/xdck.json"
headers = {
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.69",
    "Connection":"keep-alive",
    "Cookie":"__test=7ef87e272de085453da709969a222161"

}
response = requests.get(url1,headers=headers)
print(response.json())
print(type(response))
# print(response.content.decode('utf-8'))

# %% [markdown]
# ---

# %%
import requests
import json
import re

def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls


def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll



def re_findall(url): #输入原始url,返回respone
    respon=requests.get(url).text
    print(respon)
    return respon
    # def re_findall(url): #输入原始url,返回respone
    #     try:
    #         respon=requests.get(url).text
    #         print(respon)
    #         return respon
    #     except:
    #         return "失败了: "+url
#------------------------------------------
url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线

try:
    exresponse=re_findall(url1)
    print(exresponse)
    print("--------")
except Exception as e: 
    # pass
    print("失败了: ")
else:
    # pass
    
    # print("ok")
    print("执行结果是: "+findvalue(exresponse)+url7)
    print("--------")
finally:       
    print("Close")

# %% [markdown]
# 20240506

# %% [markdown]
# ## 单个url解析

# %%
import requests
import json
import re

def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll

def re_findall(url): #输入原始url,返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        return respon
    except:
        return "失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

try:
    urll=url7
    exresponse=re_findall(urll)
    # print(exresponse)
    print("="*30)
except Exception as e: 
    # pass
    print("失败了: ")
else:
    if findvalue(exresponse)=="H单仓":
        print("执行结果是:单仓 "+findvalue(exresponse)+urll)
        print("-"*20)
        for url in extract_urls(exresponse) : #寻找批量的列表网址
            # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            print(findvalue(re_findall(url))+"-"+(url))
        print("----\n")

    elif findvalue(exresponse)=="H多仓":
        print("执行结果是:多仓 "+findvalue(exresponse)+urll)
    elif findvalue(exresponse)=="H线路":
        print("执行结果是:线路  "+findvalue(exresponse)+urll)
    else:
        print("其他failure")
    print("="*30)
finally:       
    print("完成 Close")
# Out:
# --------
# 执行结果是:线路  H线路https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt
# ==============================
# 完成 Close

# %% [markdown]
# ## 多个文本url

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll

def re_findall(url): #输入原始url,返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        return respon
    except:
        return "失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
    try:
        exresponse=re_findall(urll)
        # print(exresponse)
        print("="*30)
    except Exception as e: 
        # pass
        print("失败了: ")
    else:
        if findvalue(exresponse)=="H单仓":
            print("执行结果是:单仓 "+findvalue(exresponse)+urll)
            print("-"*20)
            for url in extract_urls(exresponse) : #寻找批量的列表网址
                # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
                print(findvalue(re_findall(url))+"-"+(url))
            print("----\n")

        elif findvalue(exresponse)=="H多仓":
            print("执行结果是:多仓 "+findvalue(exresponse)+urll)
        elif findvalue(exresponse)=="H线路":
            print("执行结果是:线路  "+findvalue(exresponse)+urll)
        else:
            print("其他failure")
        print("="*30)
    finally:       
        print("完成 Close")

# strs="荷城茶秀单接口http://rihou.vip:88/荷城茶秀日后多仓http://rihou.vip:66心动单仓http://rihou.vip:666天天开心主线1http://rihou.vip:55/天天开心天天开心主线2http://rihou.cc:55/天天开心天天开心专线http://www.ttkx.site/天天开心.json追剧影视小白版https://www.123pan.com/s/DYdZVv-Hkcrv.html摸鱼https://摸鱼儿.top多多优选多仓https://duo.codered.cloud/iduo.json好趣网https://jihulab.com/yw88075/tvbox/-/raw/main/dr/js.json春盈天下https://wds.ecsxs.com/230989.json无界https://gitee.com/wj0321/tvlive/raw/main/wj.json宝盒VIPhttps://mirror.ghproxy.com/https://raw.githubusercontent.com/guot55/YGBH/main/vip2.json卧龙资源https://pastebin.com/raw/gtbKvnE1安卓哥私人接口4Khttp://liulian1993.vip:5555/tvbox/lib/ziji/ziji.json拾光4Khttps://ghps.cc/https://raw.githubusercontent.com/xmbjm/vip4K/main/4Kvip.json青木优选仓https://tvbox.aoki.fun精选仓库https://atomgit.com/shangyunvip/yingshicang/raw/master/shangyunvip.json青木精选仓https://tvbox.aoki.fun/selected"仓库名称": "①🥐饭太硬","仓库地址": "http://饭太硬.top/tv"
# "仓库名称": "②🎎多多,"仓库地址": "http://yydsys.top/duo"
# "仓库名称": "③🥣多多阿里","仓库地址": "http://yydsys.top/duo/ali "
# "仓库名称": "④🍚多多备用","仓库地址": "https://jihulab.com/duomv/apps/-/raw/main/fast.json"
# "仓库名称": "⑤🏮欧歌影视多仓库","仓库地址": " http://tv.nxog.top/nxog/ou1.php?b=欧歌"
# "仓库名称": "⑦🌟道长","仓库地址": "https://pastebin.com/raw/5NHaxyGR""

# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    # print(content)
# print(extract_urls(content))

for url in extract_urls(content) :
    print(url)
    # jiexi(url)

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll

def re_findall(url): #输入原始url,返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        return respon
    except:
        return "失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
    try:
        exresponse=re_findall(urll)
        # print(exresponse)
        print("="*30)
    except Exception as e: 
        # pass
        print("失败了: ")
    else:
        if findvalue(exresponse)=="H单仓":
            print("执行结果是:单仓 "+findvalue(exresponse)+urll)
            print("-"*20)
            for url in extract_urls(exresponse) : #寻找批量的列表网址
                # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
                print(findvalue(re_findall(url))+"-"+(url))
            print("----\n")

        elif findvalue(exresponse)=="H多仓":
            print("执行结果是:多仓 "+findvalue(exresponse)+urll)
        elif findvalue(exresponse)=="H线路":
            print("执行结果是:线路  "+findvalue(exresponse)+urll)
        else:
            print("其他failure")
        print("="*30)
    finally:       
        print("完成 Close")

jiexi(url5)
# Out:
# ==============================
# 执行结果是:单仓 H单仓https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json
# --------------------
# others----https://wds.ecsxs.com/230989.json
# H线路-https://pastebin.com/raw/5NHaxyGR
# H线路-https://raw.liucn.cc/box/m.json
# H线路-https://szyyds.cn/tv/x.json
# H线路-https://github.moeyy.xyz/https://raw.githubusercontent.com/xyq254245/xyqonlinerule/main/XYQTVBox.json
# H单仓-http://home.jundie.top:81/top98.json
# others----https://jihulab.com/ymz1231/xymz/-/raw/main/ymz
# H线路-https://github.moeyy.xyz/https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json
# H线路-https://100km.top/0
# others----https://jihulab.com/ymz1231/xymz/-/raw/main/ymshaoer
# H单仓-https://gitcode.net/u012349622/js/-/raw/master/jsm.json
# H线路-http://cdn.qiaoji8.com/tvbox.json
# H单仓-https://la.kstore.space/download/3376/ts.txt
# others----https://atomgit.com/sky4726/sky7186/raw/main/s.txt
# others----https://tvbox.wmmys.cn
# H线路-https://download.kstore.space/download/4645/Tvbox/myks/99.png
# H线路-https://chuanshuo.77blog.cn/tv.json
# others----http://www.wya6.cn/tv/yc.json
# H线路-https://xhdwc.tk/0
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/cy/
# H线路-https://tv.youdu.fan:666/PG/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H单仓-https://tv.youdu.fan:666/
# H线路-https://kjsc0310.github.io/tvy/s2.json
# others----https://raw.iqiq.io/FongMi/CatVodSpider/main/json/config.json
# H线路-http://dxawi.github.io/0/0.json
# H线路-https://weixine.net/ysc.json
# others----https://raw.iqiq.io//tv-player/tvbox-line/main/tv/fj.json
# others----https://raw.iqiq.io/XiaoYiChaHang/tvbox/main/ysj.json
# H单仓-https://www.lianyingtv.com/fast/fast
# H线路-https://download.kstore.space/download/5206/ZJ1.json
# H线路-https://download.kstore.space/download/5206/heji3.json
# H线路-https://download.kstore.space/download/5206/CCHXJK.json
# others----https://download.kstore.space/download/5206/
# H线路-https://jihulab.com/a844755785/ts/-/raw/main/shenxian0.json
# H单仓-https://download.kstore.space/download/5206/4Kshijie.json
# others----https://download.kstore.space/download/5206/
# H单仓-https://download.kstore.space/download/5206/top98.json
# H单仓-https://download.kstore.space/download/5206/heh.json
# H线路-https://jihulab.com/xo2/fty/-/raw/main/xo.json
# H线路-https://dxawi.github.io/0/0.json
# H线路-http://pandown.pro/tvbox/tvbox.json
# others----https://pan.shangui.cc/f/EDj3CD/%E5%BF%83%E5%8A%A8%E9%87%87%E9%9B%86.json
# H线路-https://jihulab.com/yw88075/tvbox/-/raw/main/dr/js.json
# H线路-https://download.kstore.space/download/2883/m3u8/dsj/guochan/mp1/1.m3u8
# others----https://cloud.lxweb.cn/f/YxzdI6/xdcj.json
# others----https://pan.shangui.cc/f/gyVYFV/
# others----https://gitlab.com/lzc1021lzc/hjfggzs.hjys/-/raw/main/hjys.free.json
# H线路-https://jihulab.com/xuanzhuapp/xzys/-/raw/main/xzvip.json
# H线路-https://gh.con.sh/https://raw.githubusercontent.com/xmbjm/vip4K/main/4Kvip.json
# H线路-https://cf.weixine.net/ysc.json
# others----https://raw.iqiq.io/liu673cn/box/main/m.json
# others----https://atomgit.com/dwc8/12/raw/master/dc.json\n
# ----
#
# ==============================
# 完成 Close

# %%
# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    # print(content)
# print(extract_urls(content))

for url in extract_urls(content) :
    print(url)
    # jiexi(url)

# %% [markdown]
# ##

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll

def re_findall(url): #输入原始url,返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        return respon
    except:
        return "失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
    try:
        exresponse=re_findall(urll)
        # print(exresponse)
        print("="*30)
    except Exception as e: 
        # pass
        print("失败了: ")
    else:
        if findvalue(exresponse)=="H单仓":
            print("执行结果是:单仓 "+findvalue(exresponse)+urll)
            # print("-"*20)
            # for url in extract_urls(exresponse) : #寻找批量的列表网址
            #     # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            #     print(findvalue(re_findall(url))+"-"+(url))
            # print("----\n")

        elif findvalue(exresponse)=="H多仓":
            print("执行结果是:多仓 "+findvalue(exresponse)+urll)
        elif findvalue(exresponse)=="H线路":
            print("执行结果是:线路  "+findvalue(exresponse)+urll)
        else:
            print("其他failure")
        print("="*30)
    finally:       
        print("完成 Close")

jiexi(url5)
# Out:
# ==============================
# 其他failure
# ==============================
# 完成 Close

# %% [markdown]
# 1212m

# %%
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls
# 打开文件并读取内容
with open('strs.txt', 'r', encoding='utf-8') as file:
    # content = file.read()
    # print(content)
    for line in file:
        print("||||"+line.strip())
        jiexi(url)


# print(extract_urls(content))

# for url in extract_urls(content)  :
#     print(url)
#     # jiexi(url)

# %% [markdown]
# ## 逐行读取 20240508

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll

def re_findall(url): #输入原始url,返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        print(requests.get(url).status_code)
        return respon
    except:
        return "失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
    try:
        exresponse=re_findall(urll)
        # print(exresponse)
        print("="*30)
    except Exception as e: 
        # pass
        print("失败了: ")
    else:
        if findvalue(exresponse)=="H单仓":
            print("执行结果是:单仓 "+findvalue(exresponse)+urll)
            # print("-"*20)
            # for url in extract_urls(exresponse) : #寻找批量的列表网址
            #     # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            #     print(findvalue(re_findall(url))+"-"+(url))
            # print("----\n")

        elif findvalue(exresponse)=="H多仓":
            print("执行结果是:多仓 "+findvalue(exresponse)+urll)
        elif findvalue(exresponse)=="H线路":
            print("执行结果是:线路  "+findvalue(exresponse)+urll)
        else:
            print("其他failure "+urll)
        print("="*30)
    finally: 
        pass
        # print("完成 Close")

jiexi(url5)
# 打开文件并读取内容
# with open('strs.txt', 'r', encoding='utf-8') as file:
#     # content = file.read()
#     # print(content)
#     # for line in file:
#         # print("|-"+line.strip())
#         # jiexi(line)
# Out:
# ==============================
# 其他failure https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json
# ==============================

# %% [markdown]
# 解析增加代理尝试

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    print(urll)
    return urll

def re_findall(url): #输入原始url,返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        print(requests.get(url).status_code)
        return respon
    except:
        return "失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexi(urll):
    try:
        exresponse=re_findall(urll)
        # print(exresponse)
        print("="*30)
    except Exception as e: 
        # pass
        print("失败了: ")
    else:
        if findvalue(exresponse)=="H单仓":
            print("执行结果是:单仓 "+findvalue(exresponse)+urll)
            # print("-"*20)
            # for url in extract_urls(exresponse) : #寻找批量的列表网址
            #     # print(addlink(url)+" -- "+findvalue(re_findall(addlink(url))))
            #     print(findvalue(re_findall(url))+"-"+(url))
            # print("----\n")

        elif findvalue(exresponse)=="H多仓":
            print("执行结果是:多仓 "+findvalue(exresponse)+urll)
        elif findvalue(exresponse)=="H线路":
            print("执行结果是:线路  "+findvalue(exresponse)+urll)
        else:
            print("其他failure "+urll)
        print("="*30)
    finally: 
        pass
        # print("完成 Close")

jiexi(url5)
# 打开文件并读取内容
# with open('strs.txt', 'r', encoding='utf-8') as file:
#     # content = file.read()
#     # print(content)
#     # for line in file:
#         # print("|-"+line.strip())
#         # jiexi(line)
# Out:
# ==============================
# 其他failure https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json
# ==============================

# %%
import requests
import json
import re,os
#	http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+
def extract_urls(text): #输入respone,寻找网址,返回列表urls
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    urls = url_pattern.findall(text)
    return urls

def findvalue(respon): #输入respond,判断单仓多仓，返回cang自定义文本
    mcang="storeHouse"
    scang="\"urls\": ["
    xlu="spider"
    if respon.find(mcang) != -1:
        cang = "H多仓"#+ respon.find(mcang)
    elif respon.find(scang) != -1:
        cang="H单仓" #+respon.find(scang)
    elif respon.find(xlu) != -1:
        cang="H线路"#+respon.find(xlu)
    else:
        cang="others---"
    return cang

def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    proxyurll=agentlink1+url
    print("代理网址： "+proxyurll)
    return proxyurll

def re_findall(url): #输入原始url,解析网站，返回respone
    try:
        respon=requests.get(url).text
        # print(respon)
        codema= requests.get(url).status_code
        print("首次解析的网址返回状态： "+str(codema))
        return respon
    except:
        try:
            respon=requests.get(addlink(url)).text
            # print(respon)
            codema= requests.get(addlink(url)).status_code
            print("代理后的网址返回状态： "+str(codema))
            return respon
        except:
            return "解析失败了: "+url

url1="http://rihou.vip:66/"   #  -花式主页
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"


re_findall(url5)
# Out:
# 首次解析的网址返回状态： 200
# '{\n    "urls": [\n        {\n            "url": "https://wds.ecsxs.com/230989.json",\n            "name": "📢春颖路线📢"\n        },\n        {\n            "url": "https://pastebin.com/raw/5NHaxyGR",\n            "name": "道长线路"\n        },\n        {\n            "url": "http://肥猫.live",\n            "name": "肥猫"\n        },\n        {\n            "url": "https://raw.liucn.cc/box/m.json",\n            "name": "🌟老刘备🌟"\n        },\n        {\n            "url": "http://小白.love/",\n            "name": "🌟肥猫🌟"\n        },\n        {\n            "url": "https://szyyds.cn/tv/x.json",\n            "name": "🌟小马🌟"\n        },\n        {\n            "url": "https://github.moeyy.xyz/https://raw.githubusercontent.com/xyq254245/xyqonlinerule/main/XYQTVBox.json",\n            "name": "🤯香雅情本地"\n        },\n        {\n            "url": "http://home.jundie.top:81/top98.json",\n            "name": "🌟俊佬🌟"\n        },\n        {\n            "url": "https://jihulab.com/ymz1231/xymz/-/raw/main/ymz",\n            "name": "🌟夜猫子🌟"\n        },\n        {\n            "url": "https://github.moeyy.xyz/https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json",\n            "name": "🚀高天JS"\n        },\n        {\n            "url": "https://100km.top/0",\n            "name": "100km"\n        },\n        {\n            "url": "https://jihulab.com/ymz1231/xymz/-/raw/main/ymshaoer",\n            "name": "miao"\n        },\n        {\n            "url": "https://gitcode.net/u012349622/js/-/raw/master/jsm.json",\n            "name": "收集线路1"\n        },\n        {\n            "url": "http://cdn.qiaoji8.com/tvbox.json",\n            "name": "qiao"\n        },\n        {\n            "url": "https://la.kstore.space/download/3376/ts.txt",\n            "name": "一起看线路"\n        },\n        {\n            "url": "https://atomgit.com/sky4726/sky7186/raw/main/s.txt",\n            "name": "SKY"\n        },\n        {\n            "url": "https://tvbox.wmmys.cn",\n            "name": "王某"\n        },\n        {\n            "url": "https://download.kstore.space/download/4645/Tvbox/myks/99.png",\n            "name": "小鱼 notionvc: e967e0cf-099c-4e50-82f7-b544ec81b2ad\xa0"\n        },\n        {\n            "url": "https://chuanshuo.77blog.cn/tv.json",\n            "name": "传说"\n        },\n        {\n            "url": "http://www.wya6.cn/tv/yc.json",\n            "name": "🏄️多多┃无意线路"\n        },\n        {\n            "url": "https://xhdwc.tk/0",\n            "name": "xhdwc"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/毒盒影视/",\n            "name": "🚀毒盒影视🚀"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/饭太硬/",\n            "name": "🚀饭太硬线"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/小米/",\n            "name": "🚀小米线路"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/肥猫/",\n            "name": "🚀肥猫线路"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/cy/",\n            "name": "🚀春盈天下"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/PG/",\n            "name": "🚀PG线路"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/香雅情XYQ/",\n            "name": "🚀香雅情XYQ"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/南风/",\n            "name": "🚀南风线路"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/骚零/",\n            "name": "🚀骚零线路"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/荷城茶秀/",\n            "name": "🚀荷城茶秀"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/短剧频道/",\n            "name": "🚀短剧频道"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/少儿频道/",\n            "name": "🚀少儿频道"\n        },\n        {\n            "url": "https://tv.youdu.fan:666/动漫频道/",\n            "name": "🚀动漫频道"\n        },\n        {\n            "url": "https://kjsc0310.github.io/tvy/s2.json",\n            "name": "🐣虞姬带飞🐣"\n        },\n        {\n       ...
