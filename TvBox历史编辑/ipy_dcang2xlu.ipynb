# %% [markdown]
# 20240509 PM 尝试 单仓 解析成线路
# 删除无效路线

# %%
import requests
import json
import re,os
import warnings 

warnings.filterwarnings("ignore")
def refindvalue(respon): #输入respond,re正则判断单仓多仓，返回cang自定义文本
    #mcang=re.search('storeHouse',respon,re.M|re.I).group()
    #scang = re.search('urls',respon,re.M|re.I).group()
    #xlu = re.search('sites',respon,re.M|re.I).group()
    try: #正常的操作
        mcang = re.search('storeHouse',respon,re.M|re.I).group()
    except :#发生异常，执行这块代码
        try:
            scang = re.search('urls',respon,re.M|re.I).group()
        except:#发生异常，执行这块代码
            try:
                xlu = re.search('sites',respon,re.M|re.I).group()
            except:#发生异常，执行这块代码
                return "正则失败"
            else: #如果没有异常执行这块代码
                return "H线路"
        else:
            return "H单仓"
    else:
        return "H多仓"
    
def addlink(url): #增加代理链接
    agentlink="http://fly.lyin.cf/?url="
    agentlink1="http://lige.unaux.com/?url="
    agentlink0=""
    urll=agentlink1+url
    # print("代理网址： "+urll)
    return urll

def re_findall(url): #输入原始url,解析网站，返回url，respone等元组
    headers={
    "Cookie":"Hm_lvt_d815f2e1f682c86565c1063aafaef292=1715176162; Hm_lpvt_d815f2e1f682c86565c1063aafaef292=1715176162; tfstk=fxg2k1gSVEL2a_igU8aaUOQXoJ4YWypCbVw_sfV4e-4scq_Z4XMWMi_ssRkZF8HaXIe_IRkssmOWReGxMPUg7pTBRYdKSDg4IOagkckz-p9BRUGxMPUMdc6Dftlz68fcjoDgru281Z4gnlXlqW2uIP4iI74uTSfcmZqGZ7DZTXhNG5ZDHRmfw4bLXoyngkQG747Q0Jc0UNV-zS7gKj2PSNwY5nQEaj9VJbaxZvPIhUbqLbGIku3wLErxrXu80VCN2bZL3z2xcK78gxGZ8u0D16wmyf0L4y-Od83tZDZL-tj0Try4xqD5sB40j540Hm9VySkj_2rooCsQwcD-7raHJt2sVXua_Vp9zvlSOqE-7p8l4NBTZ0ZxWmWGboV8aJOyZMO1RXe6S7PCXGEYo7yBizIGj9QN5iu6ZGITDWVzdI4O.; __test=1af893b932aa21ad543a801402580fba",
    "Host":"lige.unaux.com",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Connection":"keep-alive"
    }
    proxy_url=addlink(url)  #增加代理函数
    try:
        respon=requests.get(url)
        codema= respon.status_code
        if codema==200:
            print("首次解析的网址返回状态： "+str(codema)+"- "+url)
            conten="首次解析状态:"+str(codema)
            return url,respon.text,conten
        else:
            respon1=requests.get(proxy_url,headers=headers)  #增加代理1函数
            codema1= respon1.status_code
            print("代理1网址返回状态： "+str(codema)+"- "+proxy_url)
            conten1="代理1网址状态: "+str(codema1)
            return proxy_url,respon1.text,conten1
    except:
        try:
            respon2=requests.get(proxy_url,headers=headers)  #增加代理2函数
            codema2= respon2.status_code,conten
            print("代理2网址返回状态： "+str(codema)+"- "+proxy_url)
            conten2="代理2网址状态: "+str(codema2)
            return proxy_url,respon2.text,conten2
        except:
            print("解析失败： "+url)
            return url,"000","解析失败了: "

url1="http://rihou.vip:66/"   #  -花式主页
url11="http://lige.unaux.com/?url=https://o.nxog.top/nxog/nxog1.php?b=欧歌" #多仓
url2="http://xn--6orp08a.4tvbox.v6.navy/无敌.json"     #  -反炸
url3="https://agit.ai/leevi/PiG/raw/branch/master/jsm.json"  #  -失败
url4="https://tvbox.meitufu.com/TVBox/tv.json" #线路
url5="https://gitee.com/jiangnandao/tvboxline/raw/master/tvbox.json" #-单仓
url55="http://lige.unaux.com/?url=http://wl.iptv8.top/wl/a/1706600423.txt"
url6="http://530.my3v.work/xdck.json" #-单仓
url7="https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt" #-单线
url8="https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"
url9="http://gh.whoneil.top/https://raw.githubusercontent.com/xiqiliuse/tvbox/main/tvbox.json"

def jiexidc(urll):
        analysis_respone=re_findall(urll) #返回元组，第一个是url，第二个是respon，第三个是状态内容
        # print(analysis_respone[2]+" 单仓"+"-"+analysis_respone[0]+"\n"+analysis_respone[1])#+analysis_respone[1])
        text=analysis_respone[1]
        try :
            json_str = text[text.index('{'):text.rindex('}')+1]  # 提取JSON字符串
            # print(text,json_str)
            jsondata = json.loads(json_str)
            datas=jsondata['urls']
            x=len(datas)
            print('总线路条数：',x)
            for data in datas:
                testurl=data['url']
                try:
                    rnse = requests.get(testurl,verify=False,timeout =60)
                    if rnse.status_code==200:
                        pass
                        # print(data['name'],data['url'],"成功",)
                    else:
                        # print(data['name'],data['url'],"失败")
                        datas.remove(data)
                        # print('已删除当前失败',data['name'])
                except Exception:
                    # print(data['name'],data['url'],"error")
                    datas.remove(data)
                    # print('已删除当前error',data['name'])
                else:
                    pass
                finally:
                    pass
            y=len(datas) #成功路线
            print('成功路线条数：',y)
            dict2={}
            dict2['urls']=datas
            savejson2=json.dumps(datas, indent=4, ensure_ascii=False)
            with open('tvboxdcjx.json', "a", encoding="utf-8") as file:
                file.write(savejson2)
                file.close()
        except:
            print("解析失败11")
# jiexidc(url5)
with open('strsdc.txt', 'r', encoding='utf-8') as file:
    for line in file:
        lineurl=line.strip()
        jiexidc(lineurl)
# Out:
# 首次解析的网址返回状态： 200- http://home.jundie.top:81/top98.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://52pan.top:81/api/v3/file/get/174964/%E5%90%BE%E7%88%B1%E8%AF%84%E6%B5%8B.m3u?sign=rPssLoffquDXszCARt6UNF8MobSa1FA27XomzOluJBY%3D%3A0
# 解析失败11
# 首次解析的网址返回状态： 200- https://www.lianyingtv.com/fast/fast
# 解析失败11
# 首次解析的网址返回状态： 200- https://nxog.eu.org/nxog/ou1.php?b=欧歌
# 总线路条数： 26
# 成功路线条数： 25
# 首次解析的网址返回状态： 200- https://raw.liucn.cc/box/dc.txt
# 总线路条数： 52
# 成功路线条数： 33
# 首次解析的网址返回状态： 200- http://wl.iptv8.top/wl/a/1706600423.txt
# 总线路条数： 17
# 成功路线条数： 11
# 首次解析的网址返回状态： 200- https://qixing.myhkw.com/DC.txt
# 总线路条数： 38
# 成功路线条数： 26
# 首次解析的网址返回状态： 200- http://tvkj.top/DC.txt
# 总线路条数： 38
# 成功路线条数： 26
# 首次解析的网址返回状态： 200- http://39.101.135.137:8686
# 总线路条数： 30
# 成功路线条数： 22
# 首次解析的网址返回状态： 200- https://cdn.jsdelivr.net/gh/GaiVmao/dianshiyuan@main/yuan2.txt
# 解析失败11
# 首次解析的网址返回状态： 200- https://pastebin.com/raw/sbPpDm9G
# 解析失败11
# 首次解析的网址返回状态： 200- https://kjsc0310.github.io/tvy/jk9.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://home.jundie.top:81/TVBox/yosakoi.json
# 解析失败11
# 首次解析的网址返回状态： 200- https://wsl201.github.io/mao/mao6.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://ztha.top/TVBox/thdjk.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://530.my3v.work/99668.json
# 解析失败11
# 首次解析的网址返回状态： 200- https://pan.shangui.cc/f/mBYNHb/%E8%9A%82%E8%9A%81%E7%AA%9D2%E5%B1%80.txt
# 总线路条数： 58
# 成功路线条数： 33
# 首次解析的网址返回状态： 200- https://pan.shangui.cc/f/X2yqFd/%E8%9A%82%E8%9A%81%E7%AA%9D3%E5%B1%80.txt
# 总线路条数： 46
# 成功路线条数： 28
# 首次解析的网址返回状态： 200- https://pan.shangui.cc/f/KDpQc6/%EF%BB%BF%E8%9A%82%E8%9A%81%E7%AA%9D1%E5%B1%80.txt
# 总线路条数： 102
# 成功路线条数： 58
# 首次解析的网址返回状态： 200- https://d.kstore.space/download/2904/236.txt
# 总线路条数： 14
# 成功路线条数： 11
# 首次解析的网址返回状态： 200- http://154.3.2.66:8889/down/YgOQS9WjkF6R.txt
# 总线路条数： 14
# 成功路线条数： 11
# 首次解析的网址返回状态： 200- http://530.my3v.work/qm.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://39.101.135.137:8686/
# 总线路条数： 30
# 成功路线条数： 21
# 首次解析的网址返回状态： 200- http://530.my3v.work/hxck.json
# 总线路条数： 36
# 成功路线条数： 21
# 首次解析的网址返回状态： 200- http://530.my3v.work/xdck.json
# 总线路条数： 42
# 成功路线条数： 27
# 首次解析的网址返回状态： 200- https://gitee.com/GK_6_0/json/raw/master/json.txt
# 总线路条数： 25
# 成功路线条数： 15
# 首次解析的网址返回状态： 200- https://jihulab.com/jw2/jyf/-/raw/main/jihu.json
# 总线路条数： 60
# 成功路线条数： 40
# 首次解析的网址返回状态： 200- http://pandown.pro/tvbox/tvbox.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://z.qiqiv.cn/123.txt
# 总线路条数： 14
# 成功路线条数： 11
# 首次解析的网址返回状态： 200- https://notabug.org/qizhen15800/My9394/raw/master/%e4%b8%8d%e8%89%af%e5%b8%85.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://cdn.qiaoji8.com/tvbox.json
# 解析失败11
# 首次解析的网址返回状态： 200- https://download.kstore.space/download/2883/1022tv.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://jxym.ygx888.com/vip/api.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://9xi4o.tk/0725.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://xhztv.top/4k.json
# 解析失败11
# 首次解析的网址返回状态： 200- http://xhztv.top/tvbox.txt
# 总线路条数： 14
# 成功路线条数： 9
# 首次解析的网址返回状态： 200- https://tv.youdu.fan:666
# 总线路条数： 14
# 成功路线条数： 14
# 首次解析的网址返回状态： 200- https://weixine.net/api.json
# 总线路条数： 4
# 成功路线条数： 2
# 首次解析的网址返回状态： 200- https://cf.weixine.net/api.json
# 总线路条数： 4
# 成功路线条数： 2
# 首次解析的网址返回状态： 200- https://gitlab.com/xmbjm/omg/-/raw/main/omg.json
# 解析失败11
# 首次解析的网址返回状态： 200- https://gitlab.com/xmbjm/dc/-/raw/main/sgdc.json
# 总线路条数： 49
# 成功路线条数： 40
# 首次解析的网址返回状态： 200- http://xktv6.icu/x
# 总线路条数： 17
# 成功路线条数： 14
