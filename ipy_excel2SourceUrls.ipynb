# %% [markdown]
# ## 20240517 Excel 内容转化为urls

# %%
from openpyxl import load_workbook
excel_file = r'D:\lxd\learn\py\tvbox\excel_xianlu.xlsx'
workbook = load_workbook(filename=excel_file)
# sheet = workbook.active  # 获取活动工作表
sheet = workbook['xl']  # 根据名称获取工作表

for row in sheet.iter_rows(values_only=True):
    # print(row)
    print(row[0],row[1])
# Out:
# 小白龙 http://39.101.135.137:8080/
# 🔘吾爱3 http://52pan.top:81/api/v3/file/get/174964/%E5%90%BE%E7%88%B1%E8%AF%84%E6%B5%8B.m3u?sign=rPssLoffquDXszCARt6UNF8MobSa1FA27XomzOluJBY%3D%3A0
# 吾爱线路 http://52pan.top:81/api/v3/file/get/174964/吾爱评测.m3u?sign=rPssLoffquDXszCARt6UNF8MobSa1FA27XomzOluJBY%3D%3A0
# XC1 http://8.210.232.168/xc.json
# TK http://9xi4o.tk/0725.json
# BP http://bp.tvbox.cam
# 🔘巧记 http://cdn.qiaoji8.com/tvbox.json
# 俊佬线路 http://home.jundie.top:81/top98.json
# YGX888 http://jxym.ygx888.com/vip/api.json
# 欧歌 http://nxog.eu.org/m/111.php?ou=公众号欧歌app&mz=index&jar=index&123&b=欧歌
# 💦思牧丨巧技巧技 http://pandown.pro/tvbox/tvbox.json
# 万达影视 http://sinopacifichk.com/box/56.txt
# 小米线路 http://xhww.fun:63/小米/DEMO.json
# XHZ http://xhztv.top/4k.json
# XHZ2 http://xhztv.top/xhz.json
# XHZ3 http://xktv6.icu/d/
# 摸鱼 http://我不是.摸鱼儿.top
# 🔘骚零 https://100km.top/0
# 运输车加速 https://cf.weixine.net/ysc.json
# 🍚饭太硬多仓仓库 https://download.kstore.space/download/2883/1022tv.json
# 🍚饭太硬多仓仓库 https://download.kstore.space/download/2883/nzk/nzk0722.json
# 小鱼 https://download.kstore.space/download/4645/Tvbox/myks/99.png
# QLKJ https://gitee.com/zhaodehe/qlkj/raw/master/ql.json
# 🚀高天JS https://github.moeyy.xyz/https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json
# 拾光T4线路： https://gitlab.com/xmbjm/dc/-/raw/main/T4.json
# 拾光单线路： https://gitlab.com/xmbjm/omg/-/raw/main/omg.json
# 机缘巧盒凯弟 https://jihulab.com/jyqhkd1/jk/-/raw/main/机缘巧盒凯弟.json
# 心魔线路 https://jihulab.com/yw88075/tvbox//raw/main/dr/js.json
# 魔饭单仓 https://jihulab.com/yw88075/tvbox/-/raw/main/dr/js.json
# 宝盒VIP https://mirror.ghproxy.com/https://raw.githubusercontent.com/guot55/YGBH/main/vip2.json
# HeCheng https://mirror.ghproxy.com/https://raw.githubusercontent.com/HeChengChaXiu/tvbox/main/hccx.json
# 爱TV自营接口单仓 https://mirror.ghproxy.com/https://raw.githubusercontent.com/txtvv/txtv/main/tvbox/0326.json
# 拾光4K https://mirror.ghproxy.com/https://raw.githubusercontent.com/xmbjm/vip4K/main/4Kvip.json
# 拾光 https://mirror.ghproxy.com/https://raw.githubusercontent.com/xmbjm/xmbjmjk/main/xmbjm.json
# 🔘江雅 https://mirror.ghproxy.com/https://raw.githubusercontent.com/xyq254245/xyqonlinerule/main/XYQTVBox.json
# ydc https://mirror.ghproxy.com/https://raw.githubusercontent.com/yudengcheng/ydcbox/main/ydc.json
# 德福苑 https://notabug.org/afecc/tvbox/raw/main/dfy.json
# 风 https://notabug.org/kite/feng/raw/master/feng.json
# WIND https://notabug.org/kite/wind/raw/master/wind.json
# qizheng https://notabug.org/qizhen15800/My9394/raw/master/%e4%b8%8d%e8%89%af%e5%b8%85.json
# 11 https://pan.shangui.cc/f/4LBAF0/ali.json
# 最牛逼接口 https://pan.shangui.cc/f/lmP0Hk/mao4.txt
# 22 https://pan.shangui.cc/f/mPecb/%E9%87%87%E9%9B%86.json
# 道长线路 https://pastebin.com/raw/5NHaxyGR
# 卧龙资源 https://pastebin.com/raw/gtbKvnE1
# yw88075 https://raw.gitmirror.com/yw88075/tvbox/main/dr/js.json
# 🔘刘备 https://raw.liucn.cc/box/m.json
# s2 https://s2.pub/cally
# 熊猫不叫猫 https://s2.pub/xmbjmxdc
# sz https://szyyds.cn/tv/x.json
# 太阳 https://tvbox.meitufu.com/TVBox/tv.json
# ysc https://weixine.net/ysc.json
# 恋影线路 https://www.lianyingtv.com/fast/fast
# 🚀骚零线路 https://xhdwc.tk/0

# %% [markdown]
# 增加列表中的字典 url

# %%
import json
from openpyxl import load_workbook
excel_file = r'D:\lxd\learn\py\tvbox\excel_xianlu.xlsx'
workbook = load_workbook(filename=excel_file)
# sheet = workbook.active  # 获取活动工作表
sheet = workbook['xl']  # 根据名称获取工作表
dict={}
listdict=[]
for row in sheet.iter_rows(values_only=True):
    # print(row[0],row[1])
    # dict.update(name=row[0],url=row[1])
    dict["name"]=row[0]
    dict["url"]=row[1]
    listdict.append(dict.copy())
# print(listdict)
dict_loaded = json.dumps(listdict, indent=4, ensure_ascii=False)
print(dict_loaded)
# Out:
# [
#     {
#         "name": "小白龙",
#         "url": "http://39.101.135.137:8080/"
#     },
#     {
#         "name": "🔘吾爱3",
#         "url": "http://52pan.top:81/api/v3/file/get/174964/%E5%90%BE%E7%88%B1%E8%AF%84%E6%B5%8B.m3u?sign=rPssLoffquDXszCARt6UNF8MobSa1FA27XomzOluJBY%3D%3A0"
#     },
#     {
#         "name": "吾爱线路",
#         "url": "http://52pan.top:81/api/v3/file/get/174964/吾爱评测.m3u?sign=rPssLoffquDXszCARt6UNF8MobSa1FA27XomzOluJBY%3D%3A0"
#     },
#     {
#         "name": "XC1",
#         "url": "http://8.210.232.168/xc.json"
#     },
#     {
#         "name": "TK",
#         "url": "http://9xi4o.tk/0725.json"
#     },
#     {
#         "name": "BP",
#         "url": "http://bp.tvbox.cam"
#     },
#     {
#         "name": "🔘巧记",
#         "url": "http://cdn.qiaoji8.com/tvbox.json"
#     },
#     {
#         "name": "俊佬线路",
#         "url": "http://home.jundie.top:81/top98.json"
#     },
#     {
#         "name": "YGX888",
#         "url": "http://jxym.ygx888.com/vip/api.json"
#     },
#     {
#         "name": "欧歌",
#         "url": "http://nxog.eu.org/m/111.php?ou=公众号欧歌app&mz=index&jar=index&123&b=欧歌"
#     },
#     {
#         "name": "💦思牧丨巧技巧技",
#         "url": "http://pandown.pro/tvbox/tvbox.json"
#     },
#     {
#         "name": "万达影视",
#         "url": "http://sinopacifichk.com/box/56.txt"
#     },
#     {
#         "name": "小米线路",
#         "url": "http://xhww.fun:63/小米/DEMO.json"
#     },
#     {
#         "name": "XHZ",
#         "url": "http://xhztv.top/4k.json"
#     },
#     {
#         "name": "XHZ2",
#         "url": "http://xhztv.top/xhz.json"
#     },
#     {
#         "name": "XHZ3",
#         "url": "http://xktv6.icu/d/"
#     },
#     {
#         "name": "摸鱼",
#         "url": "http://我不是.摸鱼儿.top"
#     },
#     {
#         "name": "🔘骚零",
#         "url": "https://100km.top/0"
#     },
#     {
#         "name": "运输车加速",
#         "url": "https://cf.weixine.net/ysc.json"
#     },
#     {
#         "name": "🍚饭太硬多仓仓库",
#         "url": "https://download.kstore.space/download/2883/1022tv.json"
#     },
#     {
#         "name": "🍚饭太硬多仓仓库",
#         "url": "https://download.kstore.space/download/2883/nzk/nzk0722.json"
#     },
#     {
#         "name": "小鱼",
#         "url": "https://download.kstore.space/download/4645/Tvbox/myks/99.png"
#     },
#     {
#         "name": "QLKJ",
#         "url": "https://gitee.com/zhaodehe/qlkj/raw/master/ql.json"
#     },
#     {
#         "name": "🚀高天JS",
#         "url": "https://github.moeyy.xyz/https://raw.githubusercontent.com/gaotianliuyun/gao/master/js.json"
#     },
#     {
#         "name": "拾光T4线路：",
#         "url": "https://gitlab.com/xmbjm/dc/-/raw/main/T4.json"
#     },
#     {
#         "name": "拾光单线路：",
#         "url": "https://gitlab.com/xmbjm/omg/-/raw/main/omg.json"
#     },
#     {
#         "name": "机缘巧盒凯弟",
#         "url": "https://jihulab.com/jyqhkd1/jk/-/raw/main/机缘巧盒凯弟.json"
#     },
#     {
#         "name": "心魔线路",
#         "url": "https://jihulab.com/yw88075/tvbox//raw/main/dr/js.json"
#     },
#     {
#         "name": "魔饭单仓",
#         "url": "https://jihulab.com/yw88075/tvbox/-/raw/main/dr/js.json"
#     },
#     {
#         "name": "宝盒VIP",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/guot55/YGBH/main/vip2.json"
#     },
#     {
#         "name": "HeCheng",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/HeChengChaXiu/tvbox/main/hccx.json"
#     },
#     {
#         "name": "爱TV自营接口单仓",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/txtvv/txtv/main/tvbox/0326.json"
#     },
#     {
#         "name": "拾光4K",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/xmbjm/vip4K/main/4Kvip.json"
#     },
#     {
#         "name": "拾光",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/xmbjm/xmbjmjk/main/xmbjm.json"
#     },
#     {
#         "name": "🔘江雅",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/xyq254245/xyqonlinerule/main/XYQTVBox.json"
#     },
#     {
#         "name": "ydc",
#         "url": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/yudengcheng/ydcbox/main/ydc.json"
#     },
#     {
#         "name": "德福苑",
#         "url": "https://notabug.org/afecc/tvbox/raw/main/dfy.json"
#     },
#     {
#         "name": "风",
#         "url": "https://notabug.org/kite/feng/raw/master/feng.json"
#     },
#     {
#         "name": "WIND",
#         "url": "https://notabug.org/kite/wind/raw/master/wind.json"
#     },
#     {
#         "name": "qizheng",
#         "url": "https://notabug.org/qizhen15800/My9394/raw/master/%e4%b8%8d%e8%89%af%e5%b8%85.json"
#     },
#     {
#         "name": 11,
#         "url": "https://pan.shangui.cc/f/4LBAF0/ali.json"
#     },
#     {
#         "name": "最牛逼接口",
#         "url": "https://pan.shangui.cc/f/lmP0Hk/mao4.txt"
#     },
#     {
#         "name": 22,
#         "url": "https://pan.shangui.cc/f/mPecb/%E9%87%87%E9%9B%86.json"
#     },
#     {
#         "name": "道长线路",
#         "url": "https://pastebin.com/raw/5NHaxyGR"
#     },
#     {
#         "name": "卧龙资源",
#         "url": "https://pastebin.com/raw/gtbKvnE1"
#     },
#     {
#         "name": "yw88075",
#         "url": "https://raw.gitmirror.com/yw88075/tvbox/main/dr/js.json"
#     },
#     {
#         "name": "🔘刘备",
#         "url": "https://raw.liucn.cc/box/m.json"
#     },
#     {
#         "name": "s2",
#         "url": "https://s2.pub/cally"
#     },
#     {
#         "name": "熊猫不叫猫",
#         "url": "https://s2.pub/xmbjmxdc"
#     },
#     {
#         "name": "sz",
#         "url": "https://szyyds.cn/tv/x.json"
#     },
#     {
#         "name": "太阳",
#         "url": "https://tvbox.meitufu.com/TVBox/tv.json"
#     },
#     {
#         "name": "ysc",
#         "url": "https://weixine.net/ysc.json"
#     },
#     {
#         "name": "恋影线路",
#         "url": "https://www.lianyingtv.com/fast/fast"
#     },
#     {
#         "name": "🚀骚零线路",
#         "url": "https://xhdwc.tk/0"
#     }
# ]

# %% [markdown]
# 多仓json

# %%
import json
from openpyxl import load_workbook
excel_file = r'D:\lxd\learn\py\tvbox\excel_xianlu.xlsx'
workbook = load_workbook(filename=excel_file)
# sheet = workbook.active  # 获取活动工作表
sheet = workbook['dc']  # 根据名称获取工作表
dict={}
listdict=[]
for row in sheet.iter_rows(values_only=True):
    # print(row[0],row[1])
    # dict.update(name=row[0],url=row[1])
    dict["sourceName"]=row[0]
    dict["sourceUrl"]=row[1]
    listdict.append(dict.copy())
# print(listdict)
dict_loaded = json.dumps(listdict, indent=4, ensure_ascii=False)
print(dict_loaded)
# Out:
# [
#     {
#         "sourceName": "🌟星星影视",
#         "sourceUrl": "http://154.3.2.66:8889/down/YgOQS9WjkF6R.txt"
#     },
#     {
#         "sourceName": "多线路",
#         "sourceUrl": "http://39.101.135.137:8686"
#     },
#     {
#         "sourceName": "🛀🏻小白影视",
#         "sourceUrl": "http://39.101.135.137:8686/"
#     },
#     {
#         "sourceName": "🥝金鹰影视",
#         "sourceUrl": "http://530.my3v.work/99668.json"
#     },
#     {
#         "sourceName": "🎇恒星影视",
#         "sourceUrl": "http://530.my3v.work/hxck.json"
#     },
#     {
#         "sourceName": "🌴青木影视",
#         "sourceUrl": "http://530.my3v.work/qm.json"
#     },
#     {
#         "sourceName": "💖心动影视",
#         "sourceUrl": "http://530.my3v.work/xdck.json"
#     },
#     {
#         "sourceName": "天微接口",
#         "sourceUrl": "http://tvkj.top/DC.txt"
#     },
#     {
#         "sourceName": "西夏仓",
#         "sourceUrl": "http://wl.iptv8.top/wl/a/1706600423.txt"
#     },
#     {
#         "sourceName": "xhz",
#         "sourceUrl": "http://xhztv.top/tvbox.txt"
#     },
#     {
#         "sourceName": "运输车加速",
#         "sourceUrl": "https://cf.weixine.net/api.json"
#     },
#     {
#         "sourceName": "🍚饭太硬仓库",
#         "sourceUrl": "https://d.kstore.space/download/2904/236.txt"
#     },
#     {
#         "sourceName": "💠水大侠影视仓库",
#         "sourceUrl": "https://gitee.com/GK_6_0/json/raw/master/json.txt"
#     },
#     {
#         "sourceName": "拾光精选单仓线路：",
#         "sourceUrl": "https://gitlab.com/xmbjm/dc/-/raw/main/sgdc.json"
#     },
#     {
#         "sourceName": "📺追剧吧影视",
#         "sourceUrl": "https://jihulab.com/jw2/jyf/-/raw/main/jihu.json"
#     },
#     {
#         "sourceName": "推荐仓库2",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/supermeguo/BoxRes/main/Myuse/lemon.json"
#     },
#     {
#         "sourceName": "推荐仓库1",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/tianya7981/jiekou/main/0709"
#     },
#     {
#         "sourceName": "心动仓库",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/txtvv/txtv/main/ku/心动仓库.txt"
#     },
#     {
#         "sourceName": "爱TV自营接口",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/txtvv/txtv/main/tvbox/cang.json"
#     },
#     {
#         "sourceName": "🥥拾光源口",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/xmbjm/xmbjm/main/xmbjmdc.json"
#     },
#     {
#         "sourceName": "业余日后单仓",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/yyfxz/yyrh/main/fxz.json"
#     },
#     {
#         "sourceName": "挺好",
#         "sourceUrl": "https://mirror.ghproxy.com/https://raw.githubusercontent.com/ZTHA000/tvbox/main/gyck.json"
#     },
#     {
#         "sourceName": "欧歌单仓",
#         "sourceUrl": "https://nxog.eu.org/nxog/ou1.php?b=欧歌"
#     },
#     {
#         "sourceName": "🎎蚂蚁影视",
#         "sourceUrl": "https://pan.shangui.cc/f/KDpQc6/%EF%BB%BF%E8%9A%82%E8%9A%81%E7%AA%9D1%E5%B1%80.txt"
#     },
#     {
#         "sourceName": "蚂蚁窝1局",
#         "sourceUrl": "https://pan.shangui.cc/f/KDpQc6/﻿蚂蚁窝1局.txt"
#     },
#     {
#         "sourceName": "🍷蚂蚁影视二仓库",
#         "sourceUrl": "https://pan.shangui.cc/f/mBYNHb/%E8%9A%82%E8%9A%81%E7%AA%9D2%E5%B1%80.txt"
#     },
#     {
#         "sourceName": "蚂蚁窝2局",
#         "sourceUrl": "https://pan.shangui.cc/f/mBYNHb/蚂蚁窝2局.txt"
#     },
#     {
#         "sourceName": "🍷蚂蚁影视三仓库",
#         "sourceUrl": "https://pan.shangui.cc/f/X2yqFd/%E8%9A%82%E8%9A%81%E7%AA%9D3%E5%B1%80.txt"
#     },
#     {
#         "sourceName": "蚂蚁窝3局",
#         "sourceUrl": "https://pan.shangui.cc/f/X2yqFd/蚂蚁窝3局.txt"
#     },
#     {
#         "sourceName": "天微多线路",
#         "sourceUrl": "https://qixing.myhkw.com/DC.txt"
#     },
#     {
#         "sourceName": "刘备精选单仓",
#         "sourceUrl": "https://raw.liucn.cc/box/dc.txt"
#     },
#     {
#         "sourceName": "有毒",
#         "sourceUrl": "https://tv.youdu.fan:666"
#     },
#     {
#         "sourceName": "weixi",
#         "sourceUrl": "https://weixine.net/api.json"
#     }
# ]

# %% [markdown]
# 20250107多仓

# %%
import json
from openpyxl import load_workbook
excel_file = r'D:\lxd\learn\py\tvbox\excel_xianlu.xlsx'
workbook = load_workbook(filename=excel_file)
# sheet = workbook.active  # 获取活动工作表
sheet = workbook['dc']  # 根据名称获取工作表
dict={}
listdict=[]
for row in sheet.iter_rows(values_only=True):
    # print(row[0],row[1])
    # dict.update(name=row[0],url=row[1])
    dict["sourceName"]=row[0]
    dict["sourceUrl"]=row[1]
    listdict.append(dict.copy())
# print(listdict)
dict_loaded = json.dumps(listdict, indent=4, ensure_ascii=False)
print(dict_loaded)
